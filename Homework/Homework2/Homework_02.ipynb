# %% [markdown]
# # Homework #2
#
# ## Create a Farm
#
# Old McDonald is dyslexic OIEIE...
# Please help on his farm, please...
#
# Your goal is to categorize all of his animals into groups.
# example:
# - pigs are useful for there meat, skin and help improve the soil and biodiversity
#
# Create classes for all of his different types of animals
# You should have at least 5 animals on the farm ie. cows, pigs, dogs, goats
#
# VERY Poorly written example
#
# ```python
# class Animals (self):
#     self.name = name
#     self.age = age
#
# class Pets(Animals):
#     self.friend = True
#     self.eat = False
#
# class Farm (Animals):
#     self.eat = True #will it be sold for food
#     self.leather = True #will it be sold for leather
#     self.helper = False #will it be used to say plow a field
#     self.soil = True #Will it be used to help the soil
#
# class Dog(Pets)
#     self.good_boy = True
#     self.type = "type of dog"
# listOfAnimals = [Dog()]
# ```
#
#
# Your program should have an input and output allowing the user to add and remove animals.
#
# Love you !

# %%
class Animals:
        def __init__(self, name, age, species):
                self.name = name
                self.age = age
                self.species = species

class Pets(Animals):
        def __init__(self, name, age, species):
                super().__init__(name, age, species)
                self.characteristic = "Good companion" #pets are companions
                self.edibility = "Techincally...If you need to..." #it's true
                

class Livestock(Animals):
        def __init__(self, name, age, species):
                super().__init__(name, age, species)
                self.characteristic = "Makes fertilizer"
                self.edibility = "Edible" #livestock can be killed for food

AnimalsList = []

def main():
        active = True
        while (active):
                print("Welcome to Old McDonald's farm database. Choose one of the following: ")
                print("1. Add an animal")
                print("2. List all animals")
                print("3. Remove and animal")
                print("4. Exit")
                mode = input("Please enter your selection: ")

                if mode == "1":
                        name = input("Enter the animal's name: ")
                        age = input("Enter the animal's age: ")
                        species = input("Enter the animal's species: ")
                        if species == "Dog" or species == "Cat":
                                AnimalsList.append(Pets(name, age, species))
                        else:
                                AnimalsList.append(Livestock(name, age, species)) #i know this permits other non-livestock animals and spelling errors, i think this is funny
                
                elif mode == "2":
                        for Animals in AnimalsList:
                                print("Name: ", Animals.name, "Age: ", Animals.age, "Species: ", Animals.species, "Characteristic: ", Animals.characteristic, "Edibility: ", Animals.edibility)
                
                elif mode == "3":
                        remove = input("Enter the name of the animal you'd like to remove: ")
                        for Animals in AnimalsList:
                                if remove == Animals:
                                        AnimalsList.remove(remove(name, age, species))
                
                elif mode == "4":
                        print("Thanks for Old McDonald's farm database. Have a good day!")
                        active = False
                
                else:
                        print("Invalid selection. Please select again.")
main()
# Out:
# Welcome to Old McDonald's farm database. Choose one of the following:
# 1. Add an animal
# 2. List all animals
# 3. Remove and animal
# 4. Exit
# Welcome to Old McDonald's farm database. Choose one of the following:
# 1. Add an animal
# 2. List all animals
# 3. Remove and animal
# 4. Exit
# Welcome to Old McDonald's farm database. Choose one of the following:
# 1. Add an animal
# 2. List all animals
# 3. Remove and animal
# 4. Exit
# Welcome to Old McDonald's farm database. Choose one of the following:
# 1. Add an animal
# 2. List all animals
# 3. Remove and animal
# 4. Exit
# Welcome to Old McDonald's farm database. Choose one of the following:
# 1. Add an animal
# 2. List all animals
# 3. Remove and animal
# 4. Exit
# Welcome to Old McDonald's farm database. Choose one of the following:
# 1. Add an animal
# 2. List all animals
# 3. Remove and animal
# 4. Exit
# Name:  Reese Age:  6 Species:  Dog Characteristic:  Good companion Edibility:  Techincally...If you need to...
# ...
