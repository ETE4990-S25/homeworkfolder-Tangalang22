# %% [markdown]
# # Homework #5 - MatPlot and NumPy
#
#
#
# #Part 1 Mat Plot Lib
#
# Using Matplotlib create the following graphs

# %%
# Inports Here
import matplotlib

# %%
# Histogram

# %%
# Line Plot
import matplotlib.pyplot as plt

cubes = [i*i*i for i in range (1,7)]
plt.plot([1, 2, 3, 4, 5, 6], cubes)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Scatter Plot

# %%
# Pie Plot

# %%
# Area Plot

# %%
# 3d Plot - Bar Plot

# %% [markdown]
# # Part 2 - Num Py
# Like a dictionary, we can create a structured array in Numpy
#
# ```python
# data = np.array([
#     ("Billy", 32, 6),
#     ("Bob", 15, 20),
#     ("Jo", 80, 100),
#     ("Goku", 38, 9001),],
#     dtype=[("name", str, 10),
#            ("age", int),
#            ("power", int)])
# ```
#
# Using the following file https://www.kaggle.com/datasets/gregorut/videogamesales
#
# Create and sort the data by Name, Year, and NA_Sales
#
# Do not use pandas
#
# You can use this to help start you on your way
# https://stackoverflow.com/questions/57785790/construct-structured-numpy-array-from-a-file

# %%
import numpy as np
np.loadtxt("vgsales.csv", dtype={'names':('rank', 'name', 'year', 'NA_Sales')})#, 'formats':('i', 'U', 'i', 'f')})

# %%
import numpy as np
vglist = np.loadtxt("vgsales-2.csv", dtype={'names':('name', 'year', 'NA_Sales'),
                                 'formats': ('U64', 'i', 'f')},
                                 max_rows=700, #set max rows because it would trip up at every monsters, inc. game cuz of punctuation
                                 delimiter=',',
                                 skiprows=1, #skip top row where it labels each column
                                 usecols=(0,1,6)
                                 )
vglist.sort(order='name') #sorting by name
print(vglist)
# Out:
# [('"Monsters Inc"', 2002, 0.  ) ('.hack//Outbreak Part 3', 2002, 0.17)
#  ('007 Racing', 2000, 0.  ) ('007: The World is not Enough', 2000, 0.  )
#  ('18 Wheeler: American Pro Trucker', 2001, 0.  )
#  ('18 Wheeler: American Pro Trucker', 2002, 0.  )
#  ('2002 FIFA World Cup', 2002, 0.  ) ('2002 FIFA World Cup', 2002, 0.  )
#  ('4x4 EVO 2', 2001, 0.  ) ('ATV Offroad Fury', 2001, 0.  )
#  ('Ace Combat 04: Shattered Skies', 2001, 0.38)
#  ('Ace Combat 2', 1997, 0.56) ('Advance Wars', 2001, 0.  )
#  ('Aero Elite: Combat Academy', 2002, 0.  )
#  ('Age of Empires II: The Age of Kings', 1999, 0.  )
#  ('Age of Mythology', 2002, 0.  ) ('Aggressive Inline', 2002, 0.  )
#  ('Aggressive Inline', 2002, 0.  ) ('Aggressive Inline', 2002, 0.  )
#  ('AirForce Delta Storm', 2001, 0.  ) ('Airblade', 2001, 0.  )
#  ('Alien Resurrection', 2000, 0.  ) ('All-Star Baseball 2002', 2001, 0.  )
#  ('All-Star Baseball 2002', 2001, 0.  )
#  ('All-Star Baseball 2003', 2002, 0.  ) ('Alter Ego', 1985, 0.  )
#  ('Altered Beast: Guardian of the Realms', 2002, 0.  )
#  ('Alundra', 1997, 0.  ) ('Amped: Freestyle Snowboarding', 2001, 0.  )
#  ('Animal Crossing', 2001, 0.99) ('Antz Extreme Racing', 2002, 0.  )
#  ('Antz Extreme Racing', 2002, 0.  ) ('Ape Escape', 1999, 0.32)
#  ('Ape Escape 2', 2002, 0.38) ('Arctic Thunder', 2001, 0.  )
#  ('Armored Core 2', 2000, 0.23)
#  ('Armored Core 2: Another Age', 2001, 0.19)
#  ('Army Men: Air Attack 2', 2000, 0.  )
#  ('Army Men: Green Rogue', 2001, 0.  )
#  ("Army Men: Sarge's Heroes 2", 2000, 0.  )
#  ("Army Men: Sarge's Heroes 2", 2001, 0.  )
#  ('Azurik: Rise of Perathia', 2001, 0.  ) ('BMX XXX', 2002, 0.  )
#  ('BMX XXX', 2002, 0.  ) ('BMX XXX', 2002, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2001, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2002, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2002, 0.  )
#  ('Ball Breakers', 2000, 0.  ) ('Baseball Advance', 2002, 0.  )
#  ('Bass Strike', 2001, 0.  ) ('Batman: Vengeance', 2001, 0.  )
#  ('Batman: Vengeance', 2001, 0.  ) ('Battle Arena Toshinden', 1994, 0.53)
#  ('Battlefield 1942', 2002, 0.  )
#  ('Beach Spikers: Virtua Beach Volleyball', 2002, 0.  )
#  ('BeyBlade VForce: Super Tournament Battle', 2002, 0.  )
#  ('Big Mutha Truckers', 2002, 0.  ) ('Blade II', 2002, 0.  )
#  ('Blade II', 2002, 0.  ) ('Blood Omen 2', 2002, 0.  )
#  ('Blood Wake', 2001, 0.  ) ('BloodRayne', 2002, 0.  )
#  ('BloodRayne', 2002, 0.  ) ('Bloody Roar 3', 2001, 0.05)
#  ('Bloody Roar: Primal Fury', 2002, 0.  ) ('Bombastic', 2002, 0.  )
#  ('Bomberman Generation', 2002, 0.06) ('Bomberman Jetters', 2002, 0.  )
#  ('Bomberman Party Edition', 1998, 0.  )
#  ('Brave Fencer Musashi', 1998, 0.65) ('Breath of Fire', 2001, 0.06)
#  ('Breath of Fire II', 2001, 0.  ) ('Breath of Fire IV', 2000, 0.34)
#  ('Breath of Fire: Dragon Quarter', 2002, 0.  )
#  ("Britney's Dance Beat", 2002, 0.  ) ("Britney's Dance Beat", 2002, 0.  )
#  ('Broken Sword: The Shadow of the Templars', 2002, 0.  )
#  ('Burnout', 2001, 0.  ) ('Burnout', 2002, 0.  )
#  ('Bushido Blade', 1997, 0.43) ('Bust A Groove 2', 1999, 0.18)
#  ('Buzz Lightyear of Star Command', 2000, 0.  )
#  ('Capcom vs. SNK', 2000, 0.22) ('Capcom vs. SNK 2 EO', 2002, 0.  )
#  ('Capcom vs. SNK 2: Mark of the Millennium 2001', 2001, 0.3 )
#  ('Casper: Spirit Dimensions', 2001, 0.  )
#  ('Castlevania Chronicles', 2001, 0.  )
#  ('Castlevania: Circle of the Moon', 2001, 0.05)
#  ('Castlevania: Harmony of Dissonance', 2002, 0.04)
#  ('Castlevania: Symphony of the Night', 1997, 0.21)
#  ('Cel Damage', 2001, 0.  ) ('Cel Damage', 2002, 0.  )
#  ('Chase: Hollywood Stunt Driver', 2002, 0.  ) ('Chicken Run', 2000, 0.  )
#  ('Chrono Cross', 1999, 0.69) ('Circus Maximus: Chariot Wars', 2002, 0.  )
#  ('City Crisis', 2001, 0.  ) ('Clock Tower 3', 2002, 0.12)
#  ('Clock Tower II: The Struggle Within', 1998, 0.12)
#  ('Colin McRae Rally 2.0', 2000, 0.02) ('Colin McRae Rally 3', 2002, 0.  )
#  ('Colin McRae Rally 3', 2002, 0.02) ('Colony Wars', 1997, 0.  )
#  ('Combat Flight Simulator 3: Battle for Europe', 2002, 0.  )
#  ('Commandos 2: Men of Courage', 2002, 0.  )
#  ('Commandos 2: Men of Courage', 2002, 0.  ) ('Conflict Zone', 2002, 0.  )
#  ('Cossacks: European Wars', 2001, 0.  )
#  ('Crash Bandicoot 3: Warped', 1998, 1.42)
#  ('Crash Bandicoot: The Wrath of Cortex', 2001, 0.24)
#  ('Crash Bash', 2000, 0.19) ('Crash Team Racing', 1999, 0.44)
#  ('Crazy Taxi', 2001, 0.02) ('Crazy Taxi', 2001, 0.06)
#  ('Crazy Taxi 2', 2001, 0.07) ('Crazy Taxi 3: High Roller', 2002, 0.02)
#  ('Crimson Sea', 2002, 0.04)
#  ('Cubivore: Survival of the Fittest', 2002, 0.15)
#  ('Culdcept', 2002, 0.  )
#  ('Dance Dance Revolution Disney Mix', 2000, 0.  )
#  ('Dark Angel: Vampire Apocalypse', 2001, 0.  ) ('Dark Cloud', 2000, 0.08)
#  ('Dark Summit', 2002, 0.  ) ('Darkened Skye', 2002, 0.  )
#  ('Darkstone', 2001, 0.  ) ('Dave Mirra Freestyle BMX', 2000, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX: Maximum Remix', 2001, 0.  )
#  ('Dead or Alive', 1998, 0.1 ) ('Dead or Alive 3', 2001, 0.24)
#  ('Dead to Rights', 2002, 0.  ) ('DemiKids: Light Version', 2002, 0.  )
#  ('Destruction Derby Raw', 2000, 0.  ) ('Deus Ex', 2000, 0.  )
#  ('Deus Ex: The Conspiracy', 2002, 0.  ) ('Devil May Cry', 2001, 0.64)
#  ('Diablo', 1996, 0.  ) ('Diablo II', 2000, 0.  )
#  ('Diablo II: Lord of Destruction', 2001, 0.  )
#  ('Die Hard: Vendetta', 2002, 0.  )
#  ('Digimon Digital Card Battle', 1999, 0.  )
#  ('Digimon Rumble Arena', 2001, 0.  ) ('Digimon World 2', 2000, 0.16)
#  ('Dino Crisis 2', 2000, 0.28) ('Dino Stalker', 2002, 0.08)
#  ('Disaster Report', 2002, 0.15) ('Disney Golf', 2002, 0.02)
#  ('Disney Sports Skateboarding', 2002, 0.  )
#  ("Disney's Aladdin in Nasira's Revenge", 2000, 0.  )
#  ("Disney's Atlantis: The Lost Empire", 2001, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2000, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2000, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2002, 0.  )
#  ("Disney's Magical Mirror Starring Mickey Mouse", 2002, 0.  )
#  ("Disney's PK: Out of the Shadows", 2002, 0.  )
#  ("Disney's Party", 2002, 0.  )
#  ("Disney's Stitch: Experiment 626", 2002, 0.  )
#  ("Disney's Tarzan Untamed", 2001, 0.  )
#  ("Disney's Tarzan Untamed", 2001, 0.  )
#  ("Disney's The Emperor's New Groove", 2000, 0.  )
#  ("Disney's The Lion King: Simba's Mighty Adventure", 2000, 0.  )
#  ('Doom', 1992, 0.  ) ('Doom', 2001, 0.  ) ('Dragon Rage', 2001, 0.  )
#  ('Dragon Valor', 1999, 0.  ) ("Drakan: The Ancients' Gates", 2002, 0.  )
#  ('Driven', 2001, 0.  ) ('Driver', 1999, 0.02) ('Driver 2', 2000, 0.02)
#  ('Dropship: United Peace Force', 2002, 0.  )
#  ('Duke Nukem: Land of the Babes', 2000, 0.  )
#  ('Dynasty Tactics', 2002, 0.16) ('Dynasty Warriors 2', 2000, 0.34)
#  ('Dynasty Warriors 3', 2001, 1.07) ('Dynasty Warriors 3', 2002, 0.  )
#  ('Dynasty Warriors 3: Xtreme Legends', 2002, 0.74)
#  ('E.T. The Extra-Terrestrial', 2001, 0.  )
#  ('ECW Anarchy Rulz', 1999, 0.  )
#  ('ESPN Winter X Games: Snowboarding 2002', 2000, 0.  )
#  ('ESPN X Games Skateboarding', 2001, 0.  ) ('Earthworm Jim', 2001, 0.  )
#  ('Earthworm Jim 2', 2002, 0.  )
#  ('Ecco the Dolphin: Defender of the Future', 2002, 0.  )
#  ('Egg Mania: Eggstreme Madness', 2002, 0.  ) ('Empire Earth', 2001, 0.  )
#  ('Enclave', 2002, 0.  ) ('Endgame', 2002, 0.  )
#  ('Ephemeral Fantasia', 2000, 0.  )
#  ('Escape From Monkey Island', 2001, 0.  ) ('Eternal Ring', 2000, 0.1 )
#  ('EverBlue 2', 2002, 0.  ) ('EverGrace', 2000, 0.15)
#  ('Evil Dead: Hail to the King', 2000, 0.  )
#  ('Evolution Skateboarding', 2002, 0.  ) ('Evolution Worlds', 2002, 0.  )
#  ('Extermination', 2001, 0.12) ('EÂ·OÂ·E: Eve of Extinction', 2002, 0.02)
#  ('F-Zero: Maximum Velocity', 2001, 0.37) ('F1 2001', 2001, 0.  )
#  ('F1 2001', 2001, 0.  ) ('F1 2002', 2002, 0.  ) ('F1 2002', 2002, 0.02)
#  ('FIFA 2001 Major League Soccer', 2000, 0.  )
#  ('FIFA Soccer 2002', 2001, 0.  ) ('FIFA Soccer 2002', 2001, 0.  )
#  ('FIFA Soccer 2002', 2001, 0.  ) ('FIFA Soccer 2003', 2002, 0.  )
#  ('Fantavision', 2000, 0.19) ('Fatal Frame', 2001, 0.  )
#  ('Fatal Frame', 2002, 0.  ) ('Fear Effect 2: Retro Helix', 2001, 0.  )
#  ('Ferrari F355 Challenge', 2002, 0.  ) ('Fighter Maker 2', 2002, 0.  )
#  ('Final Fantasy Anthology', 1999, 0.  )
#  ('Final Fantasy Chronicles', 2001, 0.  ) ('Final Fantasy IX', 2000, 2.78)
#  ('Final Fantasy Tactics', 1997, 1.34) ('Final Fantasy VII', 1997, 3.28)
#  ('Final Fantasy VIII', 1999, 3.63) ('Final Fantasy X', 2001, 2.73)
#  ('Final Fight One', 2001, 0.08) ('Ford Racing', 2001, 0.  )
#  ('Forever Kingdom', 2001, 0.04) ('Formula One 2001', 2001, 0.  )
#  ('Frequency', 2001, 0.  ) ("Frogger 2: Swampy's Revenge", 1999, 0.  )
#  ('Frogger Beyond', 2002, 0.  ) ('Frogger: The Great Quest', 2001, 0.  )
#  ("Fur Fighters: Viggo's Revenge", 2001, 0.  )
#  ('Fuzion Frenzy', 2001, 0.  ) ('G1 Jockey 3', 2002, 0.07)
#  ('GT Advance 2: Rally Racing', 2001, 0.  ) ('Gadget Racers', 2000, 0.  )
#  ('Galerians: Ash', 2002, 0.  ) ('Gallop Racer 2001', 2001, 0.06)
#  ('Gallop Racer 2003: A New Breed', 2002, 0.12)
#  ('Gauntlet: Dark Legacy', 2001, 0.  )
#  ('Gauntlet: Dark Legacy', 2002, 0.  )
#  ('Gauntlet: Dark Legacy', 2002, 0.  )
#  ("Gekido Advance: Kintaro's Revenge", 2002, 0.  )
#  ('Genma Onimusha', 2002, 0.05) ('Giants: Citizen Kabuto', 2001, 0.  )
#  ('Gitaroo Man', 2001, 0.  ) ('Godai: Elemental Force', 2002, 0.  )
#  ('Golden Sun', 2001, 0.4 ) ('Gran Turismo', 1997, 2.54)
#  ('Gran Turismo 2', 1999, 1.69) ('Gran Turismo 3: A-Spec', 2001, 1.87)
#  ('Grand Prix Challenge', 2002, 0.  ) ('Grand Theft Auto 2', 1998, 0.  )
#  ('Grand Theft Auto III', 2001, 0.3 ) ('Grand Theft Auto III', 2002, 0.  )
#  ('Grandia', 1999, 0.  ) ('Grandia II', 2000, 0.2 )
#  ('Grandia II', 2002, 0.  ) ('Grandia Xtreme', 2002, 0.25)
#  ('Gravity Games Bike: Street Vert Dirt', 2002, 0.  )
#  ('Guilty Gear X', 2001, 0.  ) ('Guilty Gear X2', 2002, 0.16)
#  ('Guilty Gear X: Advance Edition', 2002, 0.  ) ('Gun Metal', 2002, 0.  )
#  ('Gundam Battle Assault', 1998, 0.  ) ('Gungrave', 2002, 0.  )
#  ('Gunvalkyrie', 2002, 0.  ) ('HBO Boxing', 2000, 0.  )
#  ('Half-Life', 1997, 0.09) ('Half-Life', 2001, 0.  )
#  ('Halo: Combat Evolved', 2001, 0.08)
#  ('Harry Potter and the Chamber of Secrets', 2002, 0.  )
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.  )
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.08)
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.14)
#  ('Harvest Moon: Back to Nature', 1999, 0.12) ('Herdy Gerdy', 2002, 0.  )
#  ('Hidden Invasion', 2001, 0.  ) ('Hogs of War', 2000, 0.  )
#  ('Homeworld', 1998, 0.  ) ('Hoshigami: Ruining Blue Earth', 2001, 0.  )
#  ('Hot Shots Golf 3', 2001, 1.38) ('Hot Wheels Velocity X', 2002, 0.  )
#  ('Hunter: The Reckoning', 2002, 0.  ) ('ICO', 2001, 0.  )
#  ('IL-2 Sturmovik', 2001, 0.  ) ('ISS Pro Evolution', 1998, 0.71)
#  ('Icewind Dale II', 2002, 0.  ) ('Impossible Creatures', 2002, 0.  )
#  ('Incredible Crisis', 1999, 0.  )
#  ('InuYasha: A Feudal Fairy Tale', 2002, 0.1 )
#  ('JSRF: Jet Set Radio Future', 2002, 0.03) ('Jade Cocoon 2', 2001, 0.  )
#  ('Jak and Daxter: The Precursor Legacy', 2001, 0.15)
#  ('James Bond 007: Agent Under Fire', 2001, 0.1 )
#  ("James Cameron's Dark Angel", 2002, 0.  )
#  ('Jeremy McGrath Supercross World', 2001, 0.  )
#  ('Jeremy McGrath Supercross World', 2002, 0.  )
#  ('Jimmy Neutron: Boy Genius', 2002, 0.  )
#  ('Jonny Moseley Mad Trix', 2001, 0.  )
#  ('Jurassic Park III: Park Builder', 2001, 0.  )
#  ('K-1 World Grand Prix', 2002, 0.1 ) ('KISS Pinball', 2001, 0.  )
#  ('Kabuki Warriors', 2001, 0.  ) ('Kakuto Chojin', 2002, 0.  )
#  ("Kelly Slater's Pro Surfer", 2002, 0.  )
#  ("Kelly Slater's Pro Surfer", 2002, 0.  )
#  ('Kengo: Master of Bushido', 2000, 0.06) ('Kessen', 2000, 0.41)
#  ('Kessen II', 2001, 0.2 ) ('Kinetica', 2001, 0.  )
#  ("King's Field: The Ancient City", 2001, 0.  )
#  ('Klonoa 2: Dream Champ Tournament', 2002, 0.  )
#  ("Klonoa 2: Lunatea's Veil", 2001, 0.08)
#  ('Knockout Kings 2001', 2000, 0.  ) ('Knockout Kings 2003', 2002, 0.  )
#  ('La Pucelle: Tactics', 2002, 0.  ) ('Le Mans 24 Hours', 2001, 0.02)
#  ('Legaia 2: Duel Saga', 2001, 0.  ) ('Legends of Wrestling', 2002, 0.  )
#  ('Legends of Wrestling', 2002, 0.  )
#  ('Legends of Wrestling II', 2002, 0.  )
#  ('Legends of Wrestling II', 2002, 0.  )
#  ('Legion: The Legend of Excalibur', 2002, 0.  )
#  ('Looney Tunes: Sheep Raider', 2001, 0.  ) ('Lost Kingdoms', 2002, 0.04)
#  ('Lowrider', 2002, 0.03) ('Lufia: The Ruins of Lore', 2002, 0.  )
#  ("Luigi's Mansion", 2001, 0.46)
#  ('Lunar 2: Eternal Blue Complete', 1999, 0.  )
#  ('Lunar Legend', 2002, 0.  )
#  ('Lunar: Silver Star Story Complete', 1998, 0.06)
#  ('MDK2 Armageddon', 2001, 0.  ) ('MLB 2002', 2001, 0.  )
#  ('MLB SlugFest 20-03', 2002, 0.  ) ('MLB SlugFest 20-03', 2002, 0.  )
#  ('MTV Music Generator 2', 2001, 0.  )
#  ('MX 2002 Featuring Ricky Carmichael', 2001, 0.  )
#  ('MXRider', 2001, 0.  ) ('Mad Dash Racing', 2001, 0.  )
#  ('Madden NFL 2001', 2000, 0.  ) ('Madden NFL 2001', 2000, 0.05)
#  ('Madden NFL 2002', 2001, 0.  ) ('Madden NFL 2002', 2001, 0.01)
#  ('Mafia', 2002, 0.  ) ('Magic Pengel: The Quest for Color', 2002, 0.  )
#  ('Mario Kart: Super Circuit', 2001, 0.99)
#  ('Martian Gothic: Unification', 2001, 0.  )
#  ("Mat Hoffman's Pro BMX", 2001, 0.  ) ('Max Payne', 2001, 0.  )
#  ('Max Payne', 2001, 0.  ) ('Max Payne', 2001, 0.05)
#  ('Maximo: Ghosts to Glory', 2001, 0.  )
#  ('Maximum Capacity: Hotel Giant', 2002, 0.  )
#  ('Medal of Honor', 1998, 0.  )
#  ('Medal of Honor: Underground', 2000, 0.  )
#  ('Medal of Honor: Underground', 2002, 0.  )
#  ('Mega Man Battle Network', 2001, 0.22)
#  ('Mega Man Legends 2', 2000, 0.1 ) ('Mega Man X5', 2000, 0.2 )
#  ('Mega Man X6', 2001, 0.16) ('Metal Dungeon', 2002, 0.  )
#  ('Metal Gear Solid', 1998, 0.78)
#  ('Metal Gear Solid 2: Sons of Liberty', 2001, 0.87)
#  ('Metal Slug X', 2001, 0.  ) ('MetropolisMania', 2001, 0.  )
#  ('Microsoft Train Simulator', 2001, 0.  )
#  ('Midnight Club: Street Racing', 2000, 0.02)
#  ('Midnight Club: Street Racing', 2001, 0.  )
#  ('Minority Report: Everybody Runs', 2002, 0.  )
#  ('Mister Mosquito', 2001, 0.17)
#  ('Mobile Suit Gundam: Federation vs. Zeon', 2001, 0.88)
#  ('Mobile Suit Gundam: Journey to Jaburo', 2000, 0.36)
#  ('Mobile Suit Gundam: Zeonic Front', 2001, 0.25)
#  ('Monster Rancher', 1997, 0.74) ('Monster Rancher 3', 2001, 0.14)
#  ('Monster Rancher Advance 2', 2002, 0.  )
#  ('Monsters Inc Scream Team', 2001, 0.  )
#  ('Mortal Kombat: Deadly Alliance', 2002, 0.  )
#  ('Mortal Kombat: Special Forces', 2000, 0.  ) ('MotoGP', 2000, 0.14)
#  ('MotoGP', 2002, 0.  ) ('Motocross Mania', 2001, 0.  )
#  ('Murakumo: Renegade Mech Pursuit', 2002, 0.06)
#  ('Myst III: Exile', 2002, 0.  ) ('Mystic Heroes', 2002, 0.  )
#  ('Mystic Heroes', 2002, 0.04) ('NASCAR 2001', 2000, 0.  )
#  ('NASCAR 2001', 2000, 0.  ) ('NASCAR Thunder 2002', 2001, 0.  )
#  ('NASCAR Thunder 2002', 2001, 0.  )
#  ('NASCAR: Dirt to Daytona', 2002, 0.  ) ('NBA 2K2', 2002, 0.  )
#  ('NBA 2K2', 2002, 0.  ) ('NBA Live 2001', 2000, 0.  )
#  ('NBA Live 2002', 2001, 0.  ) ('NBA Live 2002', 2001, 0.  )
#  ('NBA Live 2002', 2001, 0.  ) ('NBA ShootOut 2003', 2002, 0.  )
#  ('NBA Starting Five', 2002, 0.  ) ('NBA Street', 2001, 0.  )
#  ('NCAA College Basketball 2K3', 2002, 0.  )
#  ('NCAA College Basketball 2K3', 2002, 0.  )
#  ('NCAA Final Four 2002', 2001, 0.  ) ('NCAA Final Four 2003', 2002, 0.  )
#  ('NCAA Football 2002', 2001, 0.  ) ('NCAA Football 2003', 2002, 0.  )
#  ('NFL 2K1', 2000, 0.  ) ('NFL 2K2', 2001, 0.  ) ('NFL 2K3', 2002, 0.  )
#  ('NFL Blitz 20-02', 2002, 0.  ) ('NFL Blitz 20-03', 2002, 0.  )
#  ('NFL Fever 2002', 2000, 0.  ) ('NFL GameDay 2002', 2001, 0.  )
#  ('NFL GameDay 2002', 2001, 0.  )
#  ('NFL Quarterback Club 2002', 2001, 0.  ) ('NHL 2001', 2000, 0.  )
#  ('NHL 2001', 2000, 0.  ) ('NHL 2002', 2001, 0.  )
#  ('NHL 2002', 2001, 0.  ) ('NHL 2003', 2002, 0.  )
#  ('NHL 2003', 2002, 0.  ) ('NHL 2K3', 2002, 0.  ) ('NHL 2K3', 2002, 0.  )
#  ('NHL 2K3', 2002, 0.  ) ('NHL FaceOff 2001', 2001, 0.  )
#  ('NHL Hitz 20-02', 2001, 0.  ) ('NHL Hitz 20-02', 2001, 0.  )
#  ('NHL Hitz 20-02', 2001, 0.  ) ('NHL Hitz 20-03', 2002, 0.  )
#  ('NHL Hitz 20-03', 2002, 0.  ) ('NHL Hitz 20-03', 2002, 0.  )
#  ('Namco Museum', 2001, 0.  ) ('Namco Museum', 2001, 0.05)
#  ('Need For Speed: High Stakes', 1999, 0.  )
#  ('Need for Speed: Porsche Unleashed', 1999, 0.  )
#  ('Neverwinter Nights', 2002, 0.  )
#  ('Nickelodeon Party Blast', 2002, 0.  ) ('NightCaster', 2002, 0.  )
#  ('NightCaster II: Equinox', 2002, 0.  ) ('Ninja Assault', 2002, 0.  )
#  ("Oddworld: Abe's Exoddus", 1998, 0.  )
#  ("Oddworld: Abe's Oddysee", 1997, 0.  )
#  ("Oddworld: Munch's Oddysee", 2001, 0.  )
#  ('Okage: Shadow King', 2001, 0.08) ('Oni', 2001, 0.  )
#  ('Onimusha: Warlords', 2001, 1.09)
#  ('Orphen: Scion of Sorcery', 2000, 0.  )
#  ('Otogi: Myth of Demons', 2002, 0.03)
#  ('P.T.O. IV: Pacific Theater of Operations', 2002, 0.  )
#  ('PaRappa The Rapper', 1996, 1.46) ('PaRappa The Rapper 2', 2001, 0.  )
#  ('Pac-Man Collection', 2001, 0.05) ('Pac-Man Fever', 2001, 0.  )
#  ('Panzer Dragoon Orta', 2002, 0.04) ('Parasite Eve', 1998, 1.05)
#  ('Parasite Eve II', 1999, 0.  ) ('Paris-Dakar Rally', 2001, 0.  )
#  ('Persona 2: Eternal Punishment', 2000, 0.28)
#  ('Phantasy Star Collection', 2002, 0.  )
#  ('Phantasy Star Online', 2000, 0.2 )
#  ('Phantasy Star Online Ver. 2', 2001, 0.19) ('Phantom Crash', 2002, 0.01)
#  ('Pikmin', 2001, 0.56) ('Pirates: The Legend of Black Kat', 2002, 0.  )
#  ('Planescape: Torment', 1998, 0.  ) ('Point Blank 3', 2000, 0.  )
#  ('Portal Runner', 2001, 0.  ) ('Power Rangers: Wild Force', 2002, 0.  )
#  ('Pro Race Driver', 2002, 0.  ) ('Project Eden', 2001, 0.  )
#  ('Project Gotham Racing', 2001, 0.05)
#  ('Pryzm Chapter One: The Dark Unicorn', 2002, 0.  )
#  ('Quake III: Revolution', 2001, 0.  ) ('Quantum Redshift', 2002, 0.  )
#  ('R4: Ridge Racer Type 4', 1998, 0.79) ('RC Revenge Pro', 2000, 0.  )
#  ('RLH: Run Like Hell', 2002, 0.  ) ('RPG Maker', 1997, 0.29)
#  ('RPG Maker II', 2002, 0.  ) ('Rave Master', 2002, 0.05)
#  ('RayStorm', 1997, 0.  ) ('Rayman 2: Revolution', 2000, 0.  )
#  ('Rayman Advance', 2001, 0.  ) ('Rayman Arena', 2001, 0.  )
#  ('Rayman Arena', 2002, 0.  ) ('Red Faction', 2001, 0.  )
#  ('RedCard 20-03', 2002, 0.  ) ('RedCard 20-03', 2002, 0.  )
#  ('RedCard 20-03', 2002, 0.  ) ('Reign of Fire', 2002, 0.  )
#  ('Reign of Fire', 2002, 0.  ) ('Resident Evil', 1996, 1.11)
#  ('Resident Evil - Code: Veronica X', 2001, 0.34)
#  ('Resident Evil 2', 1998, 2.02) ('Resident Evil: Survivor', 2000, 0.29)
#  ('Rez', 2001, 0.  ) ('Ridge Racer V', 2000, 0.75)
#  ('Riding Spirits', 2002, 0.  ) ('Ring of Red', 2000, 0.  )
#  ('Road Trip', 2002, 0.  ) ('Robot Alchemic Drive', 2002, 0.  )
#  ('Robotech: Battlecry', 2002, 0.  )
#  ('Robotech: The Macross Saga', 2002, 0.  ) ('Rocky', 2002, 0.  )
#  ('Rollcage Stage II', 2000, 0.  )
#  ('Romance of the Three Kingdoms VII', 2000, 0.16)
#  ('Romance of the Three Kingdoms VIII', 2002, 0.19)
#  ('Rumble Racing', 2001, 0.  ) ('Rune: Viking Warlord', 2001, 0.  )
#  ('SSX', 2000, 0.06) ('SSX Tricky', 2001, 0.  ) ('SSX Tricky', 2001, 0.  )
#  ('SSX Tricky', 2001, 0.  )
#  ('Sabrina The Teenage Witch: Potion Commotion', 2002, 0.  )
#  ('Saiyuki: Journey West', 1999, 0.  ) ('Salt Lake 2002', 2002, 0.  )
#  ('Seaman', 1999, 0.52) ('Sega GT', 2000, 0.13)
#  ('Sega GT 2002', 2002, 0.03) ('Sega Soccer Slam', 2002, 0.  )
#  ('Sega Soccer Slam', 2002, 0.  ) ('Serious Sam', 2002, 0.  )
#  ('Shadow Hearts', 2001, 0.1 ) ('Shadow Man: 2econd Coming', 2002, 0.  )
#  ('Shadow of Destiny', 2001, 0.03)
#  ("Shaun Palmer's Pro Snowboarder", 2001, 0.  ) ('Shenmue', 1999, 0.38)
#  ('Shenmue II', 2001, 0.15) ('Shifters', 2002, 0.  )
#  ('Shining Soul', 2002, 0.09) ('Shrek', 2001, 0.  )
#  ('Shrek Extra Large', 2002, 0.  ) ('Shrek Super Party', 2002, 0.  )
#  ('Shrek Super Party', 2002, 0.  ) ('Silent Hill', 1999, 0.3 )
#  ('Silent Hill 2', 2001, 0.  )
#  ('Silent Hill 2: Restless Dreams', 2001, 0.  )
#  ('Silent Scope', 2002, 0.  ) ('Silhouette Mirage', 1998, 0.  )
#  ('Silpheed: The Lost Planet', 2000, 0.  ) ('SimCity', 1988, 0.  )
#  ('Skies of Arcadia', 2000, 0.09) ('Sky Odyssey', 2000, 0.  )
#  ('Smash Court Tennis Pro Tournament', 2002, 0.  )
#  ("Smuggler's Run", 2000, 0.  ) ("Smuggler's Run", 2002, 0.  )
#  ("Smuggler's Run: Warzones", 2002, 0.  ) ('Sneakers', 2002, 0.  )
#  ('Soldier of Fortune: Gold Edition', 2001, 0.  )
#  ('Sonic Advance', 2001, 0.22) ('Sonic Adventure 2', 2001, 0.12)
#  ('Sonic Adventure 2 Battle', 2001, 0.21) ('Soul Reaver 2', 2001, 0.  )
#  ('SoulCalibur', 1999, 0.34)
#  ("Space Channel 5: Ulala's Cosmic Attack", 2002, 0.  )
#  ('Spec Ops: Ranger Elite', 2001, 0.  ) ('Spider-Man', 2000, 0.02)
#  ('Spider-Man 2: Enter: Electro', 2001, 0.02)
#  ("Spider-Man: Mysterio's Menace", 2001, 0.  ) ('SplashDown', 2001, 0.  )
#  ('SpongeBob SquarePants: Revenge of the Flying Dutchman', 2002, 0.  )
#  ('Spy Hunter', 2001, 0.  ) ('Spyro: Season of Ice', 2001, 0.  )
#  ('Spyro: Year of the Dragon', 2000, 0.  )
#  ('Star Ocean: The Second Story', 1998, 0.72)
#  ('Star Trek: Voyager Elite Force', 2001, 0.  )
#  ('Star Wars Racer Revenge', 2002, 0.  )
#  ('Star Wars Rogue Leader: Rogue Squadron II', 2001, 0.03)
#  ('Star Wars: Demolition', 2000, 0.  ) ('Star Wars: Obi-Wan', 2001, 0.  )
#  ('Star Wars: Starfighter', 2001, 0.02)
#  ('Star Wars: Super Bombad Racing', 2001, 0.  ) ('StarCraft', 1998, 0.  )
#  ('Steel Battalion', 2002, 0.02) ('Street Fighter Alpha 3', 1998, 0.51)
#  ('Street Fighter Alpha 3', 2002, 0.  ) ('Street Fighter EX3', 2000, 0.2 )
#  ('Stretch Panic', 2001, 0.  ) ('Strider 2', 2000, 0.  )
#  ('Strikers 1945', 1998, 0.  ) ('Stronghold', 2001, 0.  )
#  ('Stunt GP', 2001, 0.  ) ('Suikoden II', 1998, 0.38)
#  ('Summoner', 2000, 0.  ) ('Summoner 2', 2002, 0.  )
#  ('Sunny Garcia Surfing', 2001, 0.  )
#  ("Super Ghouls 'n Ghosts", 2002, 0.  )
#  ('Super Mario Advance', 2001, 0.91) ('Super Monkey Ball', 2001, 0.1 )
#  ('Super Puzzle Fighter II Turbo', 1996, 0.  )
#  ('Super Smash Bros. Melee', 2001, 1.39)
#  ('Super Street Fighter II: Turbo Revival', 2001, 0.  )
#  ('Supercar Street Challenge', 2001, 0.  )
#  ('Superman: The Man of Steel', 2002, 0.  ) ('Surfing H3O', 2000, 0.  )
#  ('Swingerz Golf', 2002, 0.  ) ('Syberia', 2002, 0.  )
#  ('Syphon Filter 3', 2001, 0.  )
#  ('Tactics Ogre: The Knight of Lodis', 2001, 0.31)
#  ('Tales of Destiny II', 2000, 0.66) ('Taz Wanted', 2002, 0.  )
#  ('Taz Wanted', 2002, 0.  ) ('Tekken 2', 1996, 1.36)
#  ('Tekken 3', 1998, 1.4 ) ('Tekken Advance', 2001, 0.  )
#  ('Tekken Tag Tournament', 2000, 0.51)
#  ('Tenchu 2: Birth of the Stealth Assassins', 2000, 0.  )
#  ('Tenchu: Stealth Assassins', 1997, 0.27)
#  ('Test Drive Off-Road Wide Open', 2001, 0.  ) ('The Bouncer', 2000, 0.38)
#  ('The King of Fighters EX2: Howling Blood', 2002, 0.  )
#  ("The Legend of Alon D'ar", 2001, 0.  )
#  ('The Legend of Dragoon', 1999, 0.39) ('The Longest Journey', 1999, 0.  )
#  ('The Mummy Returns', 2001, 0.  )
#  ('The Operative: No One Lives Forever', 2002, 0.  )
#  ('The Powerpuff Girls: Chemical X-Traction', 2001, 0.  )
#  ('The Scorpion King: Rise of the Akkadian', 2002, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  ) ('The Sims', 2000, 0.  )
#  ('The Sims Deluxe', 2002, 0.  ) ('The Sims: Hot Date', 2001, 0.  )
#  ('The Sims: House Party', 2001, 0.  )
#  ('The Sims: Livin Large', 2000, 0.  )
#  ('The Terminator: Dawn of Fate', 2002, 0.  ) ('The Thing', 2002, 0.  )
#  ('The Typing of the Dead', 2000, 0.05) ('The Weakest Link', 2001, 0.  )
#  ('Theme Park Roller Coaster', 2000, 0.  )
#  ('Thunderstrike: Operation Phoenix', 2001, 0.  )
#  ('Time Crisis II', 2001, 0.  ) ('Time Crisis: Project Titan', 2001, 0.  )
#  ('TimeSplitters', 2000, 0.  ) ('Tokyo Xtreme Racer Zero', 2000, 0.15)
#  ('Tomb Raider', 1996, 0.  ) ('Tomb Raider', 1996, 0.13)
#  ('Tomb Raider: The Prophecy', 2002, 0.  )
#  ("Tony Hawk's Pro Skater", 1999, 0.02)
#  ("Tony Hawk's Pro Skater 2", 2000, 0.02)
#  ("Tony Hawk's Pro Skater 2", 2001, 0.  )
#  ("Tony Hawk's Pro Skater 2x", 2001, 0.  )
#  ("Tony Hawk's Pro Skater 3", 2001, 0.  )
#  ("Tony Hawk's Pro Skater 3", 2001, 0.01)
#  ("Tony Hawk's Pro Skater 3", 2001, 0.02)
#  ('Top Gun: Combat Zones', 2001, 0.  )
#  ('Top Gun: Combat Zones', 2002, 0.  ) ('Toy Story Racer', 2001, 0.  )
#  ('Transworld Snowboarding', 2002, 0.  ) ('Transworld Surf', 2002, 0.  )
#  ('Turok: Evolution', 2002, 0.  ) ('Twisted Metal: Black', 2001, 0.  )
#  ('Ty the Tasmanian Tiger', 2002, 0.  )
#  ('Ultimate Fighting Championship', 2000, 0.  )
#  ('Ultimate Fighting Championship: Throwdown', 2002, 0.  )
#  ('Universal Studios Theme Parks Adventure', 2001, 0.  )
#  ('Unlimited Saga', 2002, 0.56) ('Unreal Tournament', 2000, 0.  )
#  ('Unreal Tournament 2003', 2002, 0.  ) ('V-Rally 3', 2002, 0.  )
#  ('Vagrant Story', 2000, 0.3 ) ('Valkyrie Profile', 1999, 0.63)
#  ('Vampire Night', 2001, 0.  ) ('Vanguard Bandits', 1998, 0.  )
#  ("Victorious Boxers: Ippo's Road to Glory", 2000, 0.38)
#  ('Virtua Striker 2002', 2002, 0.03) ('WarJetz', 2001, 0.  )
#  ('Warcraft III: Reign of Chaos', 2002, 0.  ) ('Wario Land 4', 2001, 0.54)
#  ('Warriors of Might and Magic', 2001, 0.  )
#  ('Wave Race: Blue Storm', 2001, 0.09) ('Way of the Samurai', 2002, 0.25)
#  ('Whirl Tour', 2002, 0.  ) ('Whirl Tour', 2002, 0.  )
#  ('Wild ARMs 3', 2002, 0.29) ('WinBack: Covert Operations', 2000, 0.  )
#  ('WipEout 3', 1999, 0.  ) ('WipEout Fusion', 2002, 0.  )
#  ('WipEout XL', 1996, 0.  )
#  ('Wizardry: Tale of the Forsaken Land', 2001, 0.  )
#  ('Wolfenstein 3D', 2002, 0.  )
#  ('Woody Woodpecker: Escape from Buzz Buzzard Park', 2001, 0.  )
#  ('World Destruction League: Thunder Tanks', 2000, 0.  )
#  ('World Destruction League: Thunder Tanks', 2000, 0.  )
#  ('World Soccer Winning Eleven 6 International', 2002, 1.16)
#  ('World Tour Soccer 2002', 2001, 0.  )
#  ('World Tour Soccer 2003', 2002, 0.  )
#  ("World's Scariest Police Chases", 2001, 0.  )
#  ('Worms World Party', 2001, 0.  ) ('X-Men: Mutant Academy 2', 2001, 0.  )
#  ('X-Men: Next Dimension', 2002, 0.  )
#  ('XGIII: Extreme G Racing', 2001, 0.  ) ('XXX', 2002, 0.  )
#  ('Xenogears', 1998, 0.89) ('Yanya Caballista: City Skater', 2001, 0.  )
#  ('Zone of the Enders', 2001, 0.13)
#  ('Zone of the Enders: The Fist of Mars', 2001, 0.  )
#  ('ZooCube', 2002, 0.  )]

# %%
vglist.sort(order='year') #sorting by year
print(vglist)
# Out:
# [('Alter Ego', 1985, 0.  ) ('SimCity', 1988, 0.  ) ('Doom', 1992, 0.  )
#  ('Battle Arena Toshinden', 1994, 0.53) ('Diablo', 1996, 0.  )
#  ('PaRappa The Rapper', 1996, 1.46) ('Resident Evil', 1996, 1.11)
#  ('Super Puzzle Fighter II Turbo', 1996, 0.  ) ('Tekken 2', 1996, 1.36)
#  ('Tomb Raider', 1996, 0.  ) ('Tomb Raider', 1996, 0.13)
#  ('WipEout XL', 1996, 0.  ) ('Ace Combat 2', 1997, 0.56)
#  ('Alundra', 1997, 0.  ) ('Bushido Blade', 1997, 0.43)
#  ('Castlevania: Symphony of the Night', 1997, 0.21)
#  ('Colony Wars', 1997, 0.  ) ('Final Fantasy Tactics', 1997, 1.34)
#  ('Final Fantasy VII', 1997, 3.28) ('Gran Turismo', 1997, 2.54)
#  ('Half-Life', 1997, 0.09) ('Monster Rancher', 1997, 0.74)
#  ("Oddworld: Abe's Oddysee", 1997, 0.  ) ('RPG Maker', 1997, 0.29)
#  ('RayStorm', 1997, 0.  ) ('Tenchu: Stealth Assassins', 1997, 0.27)
#  ('Bomberman Party Edition', 1998, 0.  )
#  ('Brave Fencer Musashi', 1998, 0.65)
#  ('Clock Tower II: The Struggle Within', 1998, 0.12)
#  ('Crash Bandicoot 3: Warped', 1998, 1.42) ('Dead or Alive', 1998, 0.1 )
#  ('Grand Theft Auto 2', 1998, 0.  ) ('Gundam Battle Assault', 1998, 0.  )
#  ('Homeworld', 1998, 0.  ) ('ISS Pro Evolution', 1998, 0.71)
#  ('Lunar: Silver Star Story Complete', 1998, 0.06)
#  ('Medal of Honor', 1998, 0.  ) ('Metal Gear Solid', 1998, 0.78)
#  ("Oddworld: Abe's Exoddus", 1998, 0.  ) ('Parasite Eve', 1998, 1.05)
#  ('Planescape: Torment', 1998, 0.  )
#  ('R4: Ridge Racer Type 4', 1998, 0.79) ('Resident Evil 2', 1998, 2.02)
#  ('Silhouette Mirage', 1998, 0.  )
#  ('Star Ocean: The Second Story', 1998, 0.72) ('StarCraft', 1998, 0.  )
#  ('Street Fighter Alpha 3', 1998, 0.51) ('Strikers 1945', 1998, 0.  )
#  ('Suikoden II', 1998, 0.38) ('Tekken 3', 1998, 1.4 )
#  ('Vanguard Bandits', 1998, 0.  ) ('Xenogears', 1998, 0.89)
#  ('Age of Empires II: The Age of Kings', 1999, 0.  )
#  ('Ape Escape', 1999, 0.32) ('Bust A Groove 2', 1999, 0.18)
#  ('Chrono Cross', 1999, 0.69) ('Crash Team Racing', 1999, 0.44)
#  ('Digimon Digital Card Battle', 1999, 0.  ) ('Dragon Valor', 1999, 0.  )
#  ('Driver', 1999, 0.02) ('ECW Anarchy Rulz', 1999, 0.  )
#  ('Final Fantasy Anthology', 1999, 0.  )
#  ('Final Fantasy VIII', 1999, 3.63)
#  ("Frogger 2: Swampy's Revenge", 1999, 0.  )
#  ('Gran Turismo 2', 1999, 1.69) ('Grandia', 1999, 0.  )
#  ('Harvest Moon: Back to Nature', 1999, 0.12)
#  ('Incredible Crisis', 1999, 0.  )
#  ('Lunar 2: Eternal Blue Complete', 1999, 0.  )
#  ('Need For Speed: High Stakes', 1999, 0.  )
#  ('Need for Speed: Porsche Unleashed', 1999, 0.  )
#  ('Parasite Eve II', 1999, 0.  ) ('Saiyuki: Journey West', 1999, 0.  )
#  ('Seaman', 1999, 0.52) ('Shenmue', 1999, 0.38)
#  ('Silent Hill', 1999, 0.3 ) ('SoulCalibur', 1999, 0.34)
#  ('The Legend of Dragoon', 1999, 0.39) ('The Longest Journey', 1999, 0.  )
#  ("Tony Hawk's Pro Skater", 1999, 0.02) ('Valkyrie Profile', 1999, 0.63)
#  ('WipEout 3', 1999, 0.  ) ('007 Racing', 2000, 0.  )
#  ('007: The World is not Enough', 2000, 0.  )
#  ('Alien Resurrection', 2000, 0.  ) ('Armored Core 2', 2000, 0.23)
#  ('Army Men: Air Attack 2', 2000, 0.  )
#  ("Army Men: Sarge's Heroes 2", 2000, 0.  ) ('Ball Breakers', 2000, 0.  )
#  ('Breath of Fire IV', 2000, 0.34)
#  ('Buzz Lightyear of Star Command', 2000, 0.  )
#  ('Capcom vs. SNK', 2000, 0.22) ('Chicken Run', 2000, 0.  )
#  ('Colin McRae Rally 2.0', 2000, 0.02) ('Crash Bash', 2000, 0.19)
#  ('Dance Dance Revolution Disney Mix', 2000, 0.  )
#  ('Dark Cloud', 2000, 0.08) ('Dave Mirra Freestyle BMX', 2000, 0.  )
#  ('Destruction Derby Raw', 2000, 0.  ) ('Deus Ex', 2000, 0.  )
#  ('Diablo II', 2000, 0.  ) ('Digimon World 2', 2000, 0.16)
#  ('Dino Crisis 2', 2000, 0.28)
#  ("Disney's Aladdin in Nasira's Revenge", 2000, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2000, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2000, 0.  )
#  ("Disney's The Emperor's New Groove", 2000, 0.  )
#  ("Disney's The Lion King: Simba's Mighty Adventure", 2000, 0.  )
#  ('Driver 2', 2000, 0.02) ('Duke Nukem: Land of the Babes', 2000, 0.  )
#  ('Dynasty Warriors 2', 2000, 0.34)
#  ('ESPN Winter X Games: Snowboarding 2002', 2000, 0.  )
#  ('Ephemeral Fantasia', 2000, 0.  ) ('Eternal Ring', 2000, 0.1 )
#  ('EverGrace', 2000, 0.15) ('Evil Dead: Hail to the King', 2000, 0.  )
#  ('FIFA 2001 Major League Soccer', 2000, 0.  ) ('Fantavision', 2000, 0.19)
#  ('Final Fantasy IX', 2000, 2.78) ('Gadget Racers', 2000, 0.  )
#  ('Grandia II', 2000, 0.2 ) ('HBO Boxing', 2000, 0.  )
#  ('Hogs of War', 2000, 0.  ) ('Kengo: Master of Bushido', 2000, 0.06)
#  ('Kessen', 2000, 0.41) ('Knockout Kings 2001', 2000, 0.  )
#  ('Madden NFL 2001', 2000, 0.  ) ('Madden NFL 2001', 2000, 0.05)
#  ('Medal of Honor: Underground', 2000, 0.  )
#  ('Mega Man Legends 2', 2000, 0.1 ) ('Mega Man X5', 2000, 0.2 )
#  ('Midnight Club: Street Racing', 2000, 0.02)
#  ('Mobile Suit Gundam: Journey to Jaburo', 2000, 0.36)
#  ('Mortal Kombat: Special Forces', 2000, 0.  ) ('MotoGP', 2000, 0.14)
#  ('NASCAR 2001', 2000, 0.  ) ('NASCAR 2001', 2000, 0.  )
#  ('NBA Live 2001', 2000, 0.  ) ('NFL 2K1', 2000, 0.  )
#  ('NFL Fever 2002', 2000, 0.  ) ('NHL 2001', 2000, 0.  )
#  ('NHL 2001', 2000, 0.  ) ('Orphen: Scion of Sorcery', 2000, 0.  )
#  ('Persona 2: Eternal Punishment', 2000, 0.28)
#  ('Phantasy Star Online', 2000, 0.2 ) ('Point Blank 3', 2000, 0.  )
#  ('RC Revenge Pro', 2000, 0.  ) ('Rayman 2: Revolution', 2000, 0.  )
#  ('Resident Evil: Survivor', 2000, 0.29) ('Ridge Racer V', 2000, 0.75)
#  ('Ring of Red', 2000, 0.  ) ('Rollcage Stage II', 2000, 0.  )
#  ('Romance of the Three Kingdoms VII', 2000, 0.16) ('SSX', 2000, 0.06)
#  ('Sega GT', 2000, 0.13) ('Silpheed: The Lost Planet', 2000, 0.  )
#  ('Skies of Arcadia', 2000, 0.09) ('Sky Odyssey', 2000, 0.  )
#  ("Smuggler's Run", 2000, 0.  ) ('Spider-Man', 2000, 0.02)
#  ('Spyro: Year of the Dragon', 2000, 0.  )
#  ('Star Wars: Demolition', 2000, 0.  ) ('Street Fighter EX3', 2000, 0.2 )
#  ('Strider 2', 2000, 0.  ) ('Summoner', 2000, 0.  )
#  ('Surfing H3O', 2000, 0.  ) ('Tales of Destiny II', 2000, 0.66)
#  ('Tekken Tag Tournament', 2000, 0.51)
#  ('Tenchu 2: Birth of the Stealth Assassins', 2000, 0.  )
#  ('The Bouncer', 2000, 0.38) ('The Sims', 2000, 0.  )
#  ('The Sims: Livin Large', 2000, 0.  )
#  ('The Typing of the Dead', 2000, 0.05)
#  ('Theme Park Roller Coaster', 2000, 0.  ) ('TimeSplitters', 2000, 0.  )
#  ('Tokyo Xtreme Racer Zero', 2000, 0.15)
#  ("Tony Hawk's Pro Skater 2", 2000, 0.02)
#  ('Ultimate Fighting Championship', 2000, 0.  )
#  ('Unreal Tournament', 2000, 0.  ) ('Vagrant Story', 2000, 0.3 )
#  ("Victorious Boxers: Ippo's Road to Glory", 2000, 0.38)
#  ('WinBack: Covert Operations', 2000, 0.  )
#  ('World Destruction League: Thunder Tanks', 2000, 0.  )
#  ('World Destruction League: Thunder Tanks', 2000, 0.  )
#  ('18 Wheeler: American Pro Trucker', 2001, 0.  )
#  ('4x4 EVO 2', 2001, 0.  ) ('ATV Offroad Fury', 2001, 0.  )
#  ('Ace Combat 04: Shattered Skies', 2001, 0.38)
#  ('Advance Wars', 2001, 0.  ) ('AirForce Delta Storm', 2001, 0.  )
#  ('Airblade', 2001, 0.  ) ('All-Star Baseball 2002', 2001, 0.  )
#  ('All-Star Baseball 2002', 2001, 0.  )
#  ('Amped: Freestyle Snowboarding', 2001, 0.  )
#  ('Animal Crossing', 2001, 0.99) ('Arctic Thunder', 2001, 0.  )
#  ('Armored Core 2: Another Age', 2001, 0.19)
#  ('Army Men: Green Rogue', 2001, 0.  )
#  ("Army Men: Sarge's Heroes 2", 2001, 0.  )
#  ('Azurik: Rise of Perathia', 2001, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2001, 0.  ) ('Bass Strike', 2001, 0.  )
#  ('Batman: Vengeance', 2001, 0.  ) ('Batman: Vengeance', 2001, 0.  )
#  ('Blood Wake', 2001, 0.  ) ('Bloody Roar 3', 2001, 0.05)
#  ('Breath of Fire', 2001, 0.06) ('Breath of Fire II', 2001, 0.  )
#  ('Burnout', 2001, 0.  )
#  ('Capcom vs. SNK 2: Mark of the Millennium 2001', 2001, 0.3 )
#  ('Casper: Spirit Dimensions', 2001, 0.  )
#  ('Castlevania Chronicles', 2001, 0.  )
#  ('Castlevania: Circle of the Moon', 2001, 0.05)
#  ('Cel Damage', 2001, 0.  ) ('City Crisis', 2001, 0.  )
#  ('Cossacks: European Wars', 2001, 0.  )
#  ('Crash Bandicoot: The Wrath of Cortex', 2001, 0.24)
#  ('Crazy Taxi', 2001, 0.02) ('Crazy Taxi', 2001, 0.06)
#  ('Crazy Taxi 2', 2001, 0.07)
#  ('Dark Angel: Vampire Apocalypse', 2001, 0.  ) ('Darkstone', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX: Maximum Remix', 2001, 0.  )
#  ('Dead or Alive 3', 2001, 0.24) ('Devil May Cry', 2001, 0.64)
#  ('Diablo II: Lord of Destruction', 2001, 0.  )
#  ('Digimon Rumble Arena', 2001, 0.  )
#  ("Disney's Atlantis: The Lost Empire", 2001, 0.  )
#  ("Disney's Tarzan Untamed", 2001, 0.  )
#  ("Disney's Tarzan Untamed", 2001, 0.  ) ('Doom', 2001, 0.  )
#  ('Dragon Rage', 2001, 0.  ) ('Driven', 2001, 0.  )
#  ('Dynasty Warriors 3', 2001, 1.07)
#  ('E.T. The Extra-Terrestrial', 2001, 0.  )
#  ('ESPN X Games Skateboarding', 2001, 0.  ) ('Earthworm Jim', 2001, 0.  )
#  ('Empire Earth', 2001, 0.  ) ('Escape From Monkey Island', 2001, 0.  )
#  ('Extermination', 2001, 0.12) ('F-Zero: Maximum Velocity', 2001, 0.37)
#  ('F1 2001', 2001, 0.  ) ('F1 2001', 2001, 0.  )
#  ('FIFA Soccer 2002', 2001, 0.  ) ('FIFA Soccer 2002', 2001, 0.  )
#  ('FIFA Soccer 2002', 2001, 0.  ) ('Fatal Frame', 2001, 0.  )
#  ('Fear Effect 2: Retro Helix', 2001, 0.  )
#  ('Final Fantasy Chronicles', 2001, 0.  ) ('Final Fantasy X', 2001, 2.73)
#  ('Final Fight One', 2001, 0.08) ('Ford Racing', 2001, 0.  )
#  ('Forever Kingdom', 2001, 0.04) ('Formula One 2001', 2001, 0.  )
#  ('Frequency', 2001, 0.  ) ('Frogger: The Great Quest', 2001, 0.  )
#  ("Fur Fighters: Viggo's Revenge", 2001, 0.  )
#  ('Fuzion Frenzy', 2001, 0.  ) ('GT Advance 2: Rally Racing', 2001, 0.  )
#  ('Gallop Racer 2001', 2001, 0.06) ('Gauntlet: Dark Legacy', 2001, 0.  )
#  ('Giants: Citizen Kabuto', 2001, 0.  ) ('Gitaroo Man', 2001, 0.  )
#  ('Golden Sun', 2001, 0.4 ) ('Gran Turismo 3: A-Spec', 2001, 1.87)
#  ('Grand Theft Auto III', 2001, 0.3 ) ('Guilty Gear X', 2001, 0.  )
#  ('Half-Life', 2001, 0.  ) ('Halo: Combat Evolved', 2001, 0.08)
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.  )
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.08)
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.14)
#  ('Hidden Invasion', 2001, 0.  )
#  ('Hoshigami: Ruining Blue Earth', 2001, 0.  )
#  ('Hot Shots Golf 3', 2001, 1.38) ('ICO', 2001, 0.  )
#  ('IL-2 Sturmovik', 2001, 0.  ) ('Jade Cocoon 2', 2001, 0.  )
#  ('Jak and Daxter: The Precursor Legacy', 2001, 0.15)
#  ('James Bond 007: Agent Under Fire', 2001, 0.1 )
#  ('Jeremy McGrath Supercross World', 2001, 0.  )
#  ('Jonny Moseley Mad Trix', 2001, 0.  )
#  ('Jurassic Park III: Park Builder', 2001, 0.  )
#  ('KISS Pinball', 2001, 0.  ) ('Kabuki Warriors', 2001, 0.  )
#  ('Kessen II', 2001, 0.2 ) ('Kinetica', 2001, 0.  )
#  ("King's Field: The Ancient City", 2001, 0.  )
#  ("Klonoa 2: Lunatea's Veil", 2001, 0.08) ('Le Mans 24 Hours', 2001, 0.02)
#  ('Legaia 2: Duel Saga', 2001, 0.  )
#  ('Looney Tunes: Sheep Raider', 2001, 0.  )
#  ("Luigi's Mansion", 2001, 0.46) ('MDK2 Armageddon', 2001, 0.  )
#  ('MLB 2002', 2001, 0.  ) ('MTV Music Generator 2', 2001, 0.  )
#  ('MX 2002 Featuring Ricky Carmichael', 2001, 0.  )
#  ('MXRider', 2001, 0.  ) ('Mad Dash Racing', 2001, 0.  )
#  ('Madden NFL 2002', 2001, 0.  ) ('Madden NFL 2002', 2001, 0.01)
#  ('Mario Kart: Super Circuit', 2001, 0.99)
#  ('Martian Gothic: Unification', 2001, 0.  )
#  ("Mat Hoffman's Pro BMX", 2001, 0.  ) ('Max Payne', 2001, 0.  )
#  ('Max Payne', 2001, 0.  ) ('Max Payne', 2001, 0.05)
#  ('Maximo: Ghosts to Glory', 2001, 0.  )
#  ('Mega Man Battle Network', 2001, 0.22) ('Mega Man X6', 2001, 0.16)
#  ('Metal Gear Solid 2: Sons of Liberty', 2001, 0.87)
#  ('Metal Slug X', 2001, 0.  ) ('MetropolisMania', 2001, 0.  )
#  ('Microsoft Train Simulator', 2001, 0.  )
#  ('Midnight Club: Street Racing', 2001, 0.  )
#  ('Mister Mosquito', 2001, 0.17)
#  ('Mobile Suit Gundam: Federation vs. Zeon', 2001, 0.88)
#  ('Mobile Suit Gundam: Zeonic Front', 2001, 0.25)
#  ('Monster Rancher 3', 2001, 0.14)
#  ('Monsters Inc Scream Team', 2001, 0.  ) ('Motocross Mania', 2001, 0.  )
#  ('NASCAR Thunder 2002', 2001, 0.  ) ('NASCAR Thunder 2002', 2001, 0.  )
#  ('NBA Live 2002', 2001, 0.  ) ('NBA Live 2002', 2001, 0.  )
#  ('NBA Live 2002', 2001, 0.  ) ('NBA Street', 2001, 0.  )
#  ('NCAA Final Four 2002', 2001, 0.  ) ('NCAA Football 2002', 2001, 0.  )
#  ('NFL 2K2', 2001, 0.  ) ('NFL GameDay 2002', 2001, 0.  )
#  ('NFL GameDay 2002', 2001, 0.  )
#  ('NFL Quarterback Club 2002', 2001, 0.  ) ('NHL 2002', 2001, 0.  )
#  ('NHL 2002', 2001, 0.  ) ('NHL FaceOff 2001', 2001, 0.  )
#  ('NHL Hitz 20-02', 2001, 0.  ) ('NHL Hitz 20-02', 2001, 0.  )
#  ('NHL Hitz 20-02', 2001, 0.  ) ('Namco Museum', 2001, 0.  )
#  ('Namco Museum', 2001, 0.05) ("Oddworld: Munch's Oddysee", 2001, 0.  )
#  ('Okage: Shadow King', 2001, 0.08) ('Oni', 2001, 0.  )
#  ('Onimusha: Warlords', 2001, 1.09) ('PaRappa The Rapper 2', 2001, 0.  )
#  ('Pac-Man Collection', 2001, 0.05) ('Pac-Man Fever', 2001, 0.  )
#  ('Paris-Dakar Rally', 2001, 0.  )
#  ('Phantasy Star Online Ver. 2', 2001, 0.19) ('Pikmin', 2001, 0.56)
#  ('Portal Runner', 2001, 0.  ) ('Project Eden', 2001, 0.  )
#  ('Project Gotham Racing', 2001, 0.05)
#  ('Quake III: Revolution', 2001, 0.  ) ('Rayman Advance', 2001, 0.  )
#  ('Rayman Arena', 2001, 0.  ) ('Red Faction', 2001, 0.  )
#  ('Resident Evil - Code: Veronica X', 2001, 0.34) ('Rez', 2001, 0.  )
#  ('Rumble Racing', 2001, 0.  ) ('Rune: Viking Warlord', 2001, 0.  )
#  ('SSX Tricky', 2001, 0.  ) ('SSX Tricky', 2001, 0.  )
#  ('SSX Tricky', 2001, 0.  ) ('Shadow Hearts', 2001, 0.1 )
#  ('Shadow of Destiny', 2001, 0.03)
#  ("Shaun Palmer's Pro Snowboarder", 2001, 0.  ) ('Shenmue II', 2001, 0.15)
#  ('Shrek', 2001, 0.  ) ('Silent Hill 2', 2001, 0.  )
#  ('Silent Hill 2: Restless Dreams', 2001, 0.  )
#  ('Soldier of Fortune: Gold Edition', 2001, 0.  )
#  ('Sonic Advance', 2001, 0.22) ('Sonic Adventure 2', 2001, 0.12)
#  ('Sonic Adventure 2 Battle', 2001, 0.21) ('Soul Reaver 2', 2001, 0.  )
#  ('Spec Ops: Ranger Elite', 2001, 0.  )
#  ('Spider-Man 2: Enter: Electro', 2001, 0.02)
#  ("Spider-Man: Mysterio's Menace", 2001, 0.  ) ('SplashDown', 2001, 0.  )
#  ('Spy Hunter', 2001, 0.  ) ('Spyro: Season of Ice', 2001, 0.  )
#  ('Star Trek: Voyager Elite Force', 2001, 0.  )
#  ('Star Wars Rogue Leader: Rogue Squadron II', 2001, 0.03)
#  ('Star Wars: Obi-Wan', 2001, 0.  ) ('Star Wars: Starfighter', 2001, 0.02)
#  ('Star Wars: Super Bombad Racing', 2001, 0.  )
#  ('Stretch Panic', 2001, 0.  ) ('Stronghold', 2001, 0.  )
#  ('Stunt GP', 2001, 0.  ) ('Sunny Garcia Surfing', 2001, 0.  )
#  ('Super Mario Advance', 2001, 0.91) ('Super Monkey Ball', 2001, 0.1 )
#  ('Super Smash Bros. Melee', 2001, 1.39)
#  ('Super Street Fighter II: Turbo Revival', 2001, 0.  )
#  ('Supercar Street Challenge', 2001, 0.  ) ('Syphon Filter 3', 2001, 0.  )
#  ('Tactics Ogre: The Knight of Lodis', 2001, 0.31)
#  ('Tekken Advance', 2001, 0.  )
#  ('Test Drive Off-Road Wide Open', 2001, 0.  )
#  ("The Legend of Alon D'ar", 2001, 0.  ) ('The Mummy Returns', 2001, 0.  )
#  ('The Powerpuff Girls: Chemical X-Traction', 2001, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  )
#  ('The Sims: Hot Date', 2001, 0.  ) ('The Sims: House Party', 2001, 0.  )
#  ('The Weakest Link', 2001, 0.  )
#  ('Thunderstrike: Operation Phoenix', 2001, 0.  )
#  ('Time Crisis II', 2001, 0.  ) ('Time Crisis: Project Titan', 2001, 0.  )
#  ("Tony Hawk's Pro Skater 2", 2001, 0.  )
#  ("Tony Hawk's Pro Skater 2x", 2001, 0.  )
#  ("Tony Hawk's Pro Skater 3", 2001, 0.  )
#  ("Tony Hawk's Pro Skater 3", 2001, 0.01)
#  ("Tony Hawk's Pro Skater 3", 2001, 0.02)
#  ('Top Gun: Combat Zones', 2001, 0.  ) ('Toy Story Racer', 2001, 0.  )
#  ('Twisted Metal: Black', 2001, 0.  )
#  ('Universal Studios Theme Parks Adventure', 2001, 0.  )
#  ('Vampire Night', 2001, 0.  ) ('WarJetz', 2001, 0.  )
#  ('Wario Land 4', 2001, 0.54) ('Warriors of Might and Magic', 2001, 0.  )
#  ('Wave Race: Blue Storm', 2001, 0.09)
#  ('Wizardry: Tale of the Forsaken Land', 2001, 0.  )
#  ('Woody Woodpecker: Escape from Buzz Buzzard Park', 2001, 0.  )
#  ('World Tour Soccer 2002', 2001, 0.  )
#  ("World's Scariest Police Chases", 2001, 0.  )
#  ('Worms World Party', 2001, 0.  ) ('X-Men: Mutant Academy 2', 2001, 0.  )
#  ('XGIII: Extreme G Racing', 2001, 0.  )
#  ('Yanya Caballista: City Skater', 2001, 0.  )
#  ('Zone of the Enders', 2001, 0.13)
#  ('Zone of the Enders: The Fist of Mars', 2001, 0.  )
#  ('"Monsters Inc"', 2002, 0.  ) ('.hack//Outbreak Part 3', 2002, 0.17)
#  ('18 Wheeler: American Pro Trucker', 2002, 0.  )
#  ('2002 FIFA World Cup', 2002, 0.  ) ('2002 FIFA World Cup', 2002, 0.  )
#  ('Aero Elite: Combat Academy', 2002, 0.  )
#  ('Age of Mythology', 2002, 0.  ) ('Aggressive Inline', 2002, 0.  )
#  ('Aggressive Inline', 2002, 0.  ) ('Aggressive Inline', 2002, 0.  )
#  ('All-Star Baseball 2003', 2002, 0.  )
#  ('Altered Beast: Guardian of the Realms', 2002, 0.  )
#  ('Antz Extreme Racing', 2002, 0.  ) ('Antz Extreme Racing', 2002, 0.  )
#  ('Ape Escape 2', 2002, 0.38) ('BMX XXX', 2002, 0.  )
#  ('BMX XXX', 2002, 0.  ) ('BMX XXX', 2002, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2002, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2002, 0.  )
#  ('Baseball Advance', 2002, 0.  ) ('Battlefield 1942', 2002, 0.  )
#  ('Beach Spikers: Virtua Beach Volleyball', 2002, 0.  )
#  ('BeyBlade VForce: Super Tournament Battle', 2002, 0.  )
#  ('Big Mutha Truckers', 2002, 0.  ) ('Blade II', 2002, 0.  )
#  ('Blade II', 2002, 0.  ) ('Blood Omen 2', 2002, 0.  )
#  ('BloodRayne', 2002, 0.  ) ('BloodRayne', 2002, 0.  )
#  ('Bloody Roar: Primal Fury', 2002, 0.  ) ('Bombastic', 2002, 0.  )
#  ('Bomberman Generation', 2002, 0.06) ('Bomberman Jetters', 2002, 0.  )
#  ('Breath of Fire: Dragon Quarter', 2002, 0.  )
#  ("Britney's Dance Beat", 2002, 0.  ) ("Britney's Dance Beat", 2002, 0.  )
#  ('Broken Sword: The Shadow of the Templars', 2002, 0.  )
#  ('Burnout', 2002, 0.  ) ('Capcom vs. SNK 2 EO', 2002, 0.  )
#  ('Castlevania: Harmony of Dissonance', 2002, 0.04)
#  ('Cel Damage', 2002, 0.  ) ('Chase: Hollywood Stunt Driver', 2002, 0.  )
#  ('Circus Maximus: Chariot Wars', 2002, 0.  )
#  ('Clock Tower 3', 2002, 0.12) ('Colin McRae Rally 3', 2002, 0.  )
#  ('Colin McRae Rally 3', 2002, 0.02)
#  ('Combat Flight Simulator 3: Battle for Europe', 2002, 0.  )
#  ('Commandos 2: Men of Courage', 2002, 0.  )
#  ('Commandos 2: Men of Courage', 2002, 0.  ) ('Conflict Zone', 2002, 0.  )
#  ('Crazy Taxi 3: High Roller', 2002, 0.02) ('Crimson Sea', 2002, 0.04)
#  ('Cubivore: Survival of the Fittest', 2002, 0.15)
#  ('Culdcept', 2002, 0.  ) ('Dark Summit', 2002, 0.  )
#  ('Darkened Skye', 2002, 0.  ) ('Dead to Rights', 2002, 0.  )
#  ('DemiKids: Light Version', 2002, 0.  )
#  ('Deus Ex: The Conspiracy', 2002, 0.  )
#  ('Die Hard: Vendetta', 2002, 0.  ) ('Dino Stalker', 2002, 0.08)
#  ('Disaster Report', 2002, 0.15) ('Disney Golf', 2002, 0.02)
#  ('Disney Sports Skateboarding', 2002, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2002, 0.  )
#  ("Disney's Magical Mirror Starring Mickey Mouse", 2002, 0.  )
#  ("Disney's PK: Out of the Shadows", 2002, 0.  )
#  ("Disney's Party", 2002, 0.  )
#  ("Disney's Stitch: Experiment 626", 2002, 0.  )
#  ("Drakan: The Ancients' Gates", 2002, 0.  )
#  ('Dropship: United Peace Force', 2002, 0.  )
#  ('Dynasty Tactics', 2002, 0.16) ('Dynasty Warriors 3', 2002, 0.  )
#  ('Dynasty Warriors 3: Xtreme Legends', 2002, 0.74)
#  ('Earthworm Jim 2', 2002, 0.  )
#  ('Ecco the Dolphin: Defender of the Future', 2002, 0.  )
#  ('Egg Mania: Eggstreme Madness', 2002, 0.  ) ('Enclave', 2002, 0.  )
#  ('Endgame', 2002, 0.  ) ('EverBlue 2', 2002, 0.  )
#  ('Evolution Skateboarding', 2002, 0.  ) ('Evolution Worlds', 2002, 0.  )
#  ('EÂ·OÂ·E: Eve of Extinction', 2002, 0.02) ('F1 2002', 2002, 0.  )
#  ('F1 2002', 2002, 0.02) ('FIFA Soccer 2003', 2002, 0.  )
#  ('Fatal Frame', 2002, 0.  ) ('Ferrari F355 Challenge', 2002, 0.  )
#  ('Fighter Maker 2', 2002, 0.  ) ('Frogger Beyond', 2002, 0.  )
#  ('G1 Jockey 3', 2002, 0.07) ('Galerians: Ash', 2002, 0.  )
#  ('Gallop Racer 2003: A New Breed', 2002, 0.12)
#  ('Gauntlet: Dark Legacy', 2002, 0.  )
#  ('Gauntlet: Dark Legacy', 2002, 0.  )
#  ("Gekido Advance: Kintaro's Revenge", 2002, 0.  )
#  ('Genma Onimusha', 2002, 0.05) ('Godai: Elemental Force', 2002, 0.  )
#  ('Grand Prix Challenge', 2002, 0.  ) ('Grand Theft Auto III', 2002, 0.  )
#  ('Grandia II', 2002, 0.  ) ('Grandia Xtreme', 2002, 0.25)
#  ('Gravity Games Bike: Street Vert Dirt', 2002, 0.  )
#  ('Guilty Gear X2', 2002, 0.16)
#  ('Guilty Gear X: Advance Edition', 2002, 0.  ) ('Gun Metal', 2002, 0.  )
#  ('Gungrave', 2002, 0.  ) ('Gunvalkyrie', 2002, 0.  )
#  ('Harry Potter and the Chamber of Secrets', 2002, 0.  )
#  ('Herdy Gerdy', 2002, 0.  ) ('Hot Wheels Velocity X', 2002, 0.  )
#  ('Hunter: The Reckoning', 2002, 0.  ) ('Icewind Dale II', 2002, 0.  )
#  ('Impossible Creatures', 2002, 0.  )
#  ('InuYasha: A Feudal Fairy Tale', 2002, 0.1 )
#  ('JSRF: Jet Set Radio Future', 2002, 0.03)
#  ("James Cameron's Dark Angel", 2002, 0.  )
#  ('Jeremy McGrath Supercross World', 2002, 0.  )
#  ('Jimmy Neutron: Boy Genius', 2002, 0.  )
#  ('K-1 World Grand Prix', 2002, 0.1 ) ('Kakuto Chojin', 2002, 0.  )
#  ("Kelly Slater's Pro Surfer", 2002, 0.  )
#  ("Kelly Slater's Pro Surfer", 2002, 0.  )
#  ('Klonoa 2: Dream Champ Tournament', 2002, 0.  )
#  ('Knockout Kings 2003', 2002, 0.  ) ('La Pucelle: Tactics', 2002, 0.  )
#  ('Legends of Wrestling', 2002, 0.  ) ('Legends of Wrestling', 2002, 0.  )
#  ('Legends of Wrestling II', 2002, 0.  )
#  ('Legends of Wrestling II', 2002, 0.  )
#  ('Legion: The Legend of Excalibur', 2002, 0.  )
#  ('Lost Kingdoms', 2002, 0.04) ('Lowrider', 2002, 0.03)
#  ('Lufia: The Ruins of Lore', 2002, 0.  ) ('Lunar Legend', 2002, 0.  )
#  ('MLB SlugFest 20-03', 2002, 0.  ) ('MLB SlugFest 20-03', 2002, 0.  )
#  ('Mafia', 2002, 0.  ) ('Magic Pengel: The Quest for Color', 2002, 0.  )
#  ('Maximum Capacity: Hotel Giant', 2002, 0.  )
#  ('Medal of Honor: Underground', 2002, 0.  ) ('Metal Dungeon', 2002, 0.  )
#  ('Minority Report: Everybody Runs', 2002, 0.  )
#  ('Monster Rancher Advance 2', 2002, 0.  )
#  ('Mortal Kombat: Deadly Alliance', 2002, 0.  ) ('MotoGP', 2002, 0.  )
#  ('Murakumo: Renegade Mech Pursuit', 2002, 0.06)
#  ('Myst III: Exile', 2002, 0.  ) ('Mystic Heroes', 2002, 0.  )
#  ('Mystic Heroes', 2002, 0.04) ('NASCAR: Dirt to Daytona', 2002, 0.  )
#  ('NBA 2K2', 2002, 0.  ) ('NBA 2K2', 2002, 0.  )
#  ('NBA ShootOut 2003', 2002, 0.  ) ('NBA Starting Five', 2002, 0.  )
#  ('NCAA College Basketball 2K3', 2002, 0.  )
#  ('NCAA College Basketball 2K3', 2002, 0.  )
#  ('NCAA Final Four 2003', 2002, 0.  ) ('NCAA Football 2003', 2002, 0.  )
#  ('NFL 2K3', 2002, 0.  ) ('NFL Blitz 20-02', 2002, 0.  )
#  ('NFL Blitz 20-03', 2002, 0.  ) ('NHL 2003', 2002, 0.  )
#  ('NHL 2003', 2002, 0.  ) ('NHL 2K3', 2002, 0.  ) ('NHL 2K3', 2002, 0.  )
#  ('NHL 2K3', 2002, 0.  ) ('NHL Hitz 20-03', 2002, 0.  )
#  ('NHL Hitz 20-03', 2002, 0.  ) ('NHL Hitz 20-03', 2002, 0.  )
#  ('Neverwinter Nights', 2002, 0.  )
#  ('Nickelodeon Party Blast', 2002, 0.  ) ('NightCaster', 2002, 0.  )
#  ('NightCaster II: Equinox', 2002, 0.  ) ('Ninja Assault', 2002, 0.  )
#  ('Otogi: Myth of Demons', 2002, 0.03)
#  ('P.T.O. IV: Pacific Theater of Operations', 2002, 0.  )
#  ('Panzer Dragoon Orta', 2002, 0.04)
#  ('Phantasy Star Collection', 2002, 0.  ) ('Phantom Crash', 2002, 0.01)
#  ('Pirates: The Legend of Black Kat', 2002, 0.  )
#  ('Power Rangers: Wild Force', 2002, 0.  ) ('Pro Race Driver', 2002, 0.  )
#  ('Pryzm Chapter One: The Dark Unicorn', 2002, 0.  )
#  ('Quantum Redshift', 2002, 0.  ) ('RLH: Run Like Hell', 2002, 0.  )
#  ('RPG Maker II', 2002, 0.  ) ('Rave Master', 2002, 0.05)
#  ('Rayman Arena', 2002, 0.  ) ('RedCard 20-03', 2002, 0.  )
#  ('RedCard 20-03', 2002, 0.  ) ('RedCard 20-03', 2002, 0.  )
#  ('Reign of Fire', 2002, 0.  ) ('Reign of Fire', 2002, 0.  )
#  ('Riding Spirits', 2002, 0.  ) ('Road Trip', 2002, 0.  )
#  ('Robot Alchemic Drive', 2002, 0.  ) ('Robotech: Battlecry', 2002, 0.  )
#  ('Robotech: The Macross Saga', 2002, 0.  ) ('Rocky', 2002, 0.  )
#  ('Romance of the Three Kingdoms VIII', 2002, 0.19)
#  ('Sabrina The Teenage Witch: Potion Commotion', 2002, 0.  )
#  ('Salt Lake 2002', 2002, 0.  ) ('Sega GT 2002', 2002, 0.03)
#  ('Sega Soccer Slam', 2002, 0.  ) ('Sega Soccer Slam', 2002, 0.  )
#  ('Serious Sam', 2002, 0.  ) ('Shadow Man: 2econd Coming', 2002, 0.  )
#  ('Shifters', 2002, 0.  ) ('Shining Soul', 2002, 0.09)
#  ('Shrek Extra Large', 2002, 0.  ) ('Shrek Super Party', 2002, 0.  )
#  ('Shrek Super Party', 2002, 0.  ) ('Silent Scope', 2002, 0.  )
#  ('Smash Court Tennis Pro Tournament', 2002, 0.  )
#  ("Smuggler's Run", 2002, 0.  ) ("Smuggler's Run: Warzones", 2002, 0.  )
#  ('Sneakers', 2002, 0.  )
#  ("Space Channel 5: Ulala's Cosmic Attack", 2002, 0.  )
#  ('SpongeBob SquarePants: Revenge of the Flying Dutchman', 2002, 0.  )
#  ('Star Wars Racer Revenge', 2002, 0.  ) ('Steel Battalion', 2002, 0.02)
#  ('Street Fighter Alpha 3', 2002, 0.  ) ('Summoner 2', 2002, 0.  )
#  ("Super Ghouls 'n Ghosts", 2002, 0.  )
#  ('Superman: The Man of Steel', 2002, 0.  ) ('Swingerz Golf', 2002, 0.  )
#  ('Syberia', 2002, 0.  ) ('Taz Wanted', 2002, 0.  )
#  ('Taz Wanted', 2002, 0.  )
#  ('The King of Fighters EX2: Howling Blood', 2002, 0.  )
#  ('The Operative: No One Lives Forever', 2002, 0.  )
#  ('The Scorpion King: Rise of the Akkadian', 2002, 0.  )
#  ('The Sims Deluxe', 2002, 0.  )
#  ('The Terminator: Dawn of Fate', 2002, 0.  ) ('The Thing', 2002, 0.  )
#  ('Tomb Raider: The Prophecy', 2002, 0.  )
#  ('Top Gun: Combat Zones', 2002, 0.  )
#  ('Transworld Snowboarding', 2002, 0.  ) ('Transworld Surf', 2002, 0.  )
#  ('Turok: Evolution', 2002, 0.  ) ('Ty the Tasmanian Tiger', 2002, 0.  )
#  ('Ultimate Fighting Championship: Throwdown', 2002, 0.  )
#  ('Unlimited Saga', 2002, 0.56) ('Unreal Tournament 2003', 2002, 0.  )
#  ('V-Rally 3', 2002, 0.  ) ('Virtua Striker 2002', 2002, 0.03)
#  ('Warcraft III: Reign of Chaos', 2002, 0.  )
#  ('Way of the Samurai', 2002, 0.25) ('Whirl Tour', 2002, 0.  )
#  ('Whirl Tour', 2002, 0.  ) ('Wild ARMs 3', 2002, 0.29)
#  ('WipEout Fusion', 2002, 0.  ) ('Wolfenstein 3D', 2002, 0.  )
#  ('World Soccer Winning Eleven 6 International', 2002, 1.16)
#  ('World Tour Soccer 2003', 2002, 0.  )
#  ('X-Men: Next Dimension', 2002, 0.  ) ('XXX', 2002, 0.  )
#  ('ZooCube', 2002, 0.  )]

# %%
vglist.sort(order='NA_Sales') #sorting by NA sales
print(vglist)
# Out:
# [('"Monsters Inc"', 2002, 0.  ) ('007 Racing', 2000, 0.  )
#  ('007: The World is not Enough', 2000, 0.  )
#  ('18 Wheeler: American Pro Trucker', 2001, 0.  )
#  ('18 Wheeler: American Pro Trucker', 2002, 0.  )
#  ('2002 FIFA World Cup', 2002, 0.  ) ('2002 FIFA World Cup', 2002, 0.  )
#  ('4x4 EVO 2', 2001, 0.  ) ('ATV Offroad Fury', 2001, 0.  )
#  ('Advance Wars', 2001, 0.  ) ('Aero Elite: Combat Academy', 2002, 0.  )
#  ('Age of Empires II: The Age of Kings', 1999, 0.  )
#  ('Age of Mythology', 2002, 0.  ) ('Aggressive Inline', 2002, 0.  )
#  ('Aggressive Inline', 2002, 0.  ) ('Aggressive Inline', 2002, 0.  )
#  ('AirForce Delta Storm', 2001, 0.  ) ('Airblade', 2001, 0.  )
#  ('Alien Resurrection', 2000, 0.  ) ('All-Star Baseball 2002', 2001, 0.  )
#  ('All-Star Baseball 2002', 2001, 0.  )
#  ('All-Star Baseball 2003', 2002, 0.  ) ('Alter Ego', 1985, 0.  )
#  ('Altered Beast: Guardian of the Realms', 2002, 0.  )
#  ('Alundra', 1997, 0.  ) ('Amped: Freestyle Snowboarding', 2001, 0.  )
#  ('Antz Extreme Racing', 2002, 0.  ) ('Antz Extreme Racing', 2002, 0.  )
#  ('Arctic Thunder', 2001, 0.  ) ('Army Men: Air Attack 2', 2000, 0.  )
#  ('Army Men: Green Rogue', 2001, 0.  )
#  ("Army Men: Sarge's Heroes 2", 2000, 0.  )
#  ("Army Men: Sarge's Heroes 2", 2001, 0.  )
#  ('Azurik: Rise of Perathia', 2001, 0.  ) ('BMX XXX', 2002, 0.  )
#  ('BMX XXX', 2002, 0.  ) ('BMX XXX', 2002, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2001, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2002, 0.  )
#  ("Baldur's Gate: Dark Alliance", 2002, 0.  )
#  ('Ball Breakers', 2000, 0.  ) ('Baseball Advance', 2002, 0.  )
#  ('Bass Strike', 2001, 0.  ) ('Batman: Vengeance', 2001, 0.  )
#  ('Batman: Vengeance', 2001, 0.  ) ('Battlefield 1942', 2002, 0.  )
#  ('Beach Spikers: Virtua Beach Volleyball', 2002, 0.  )
#  ('BeyBlade VForce: Super Tournament Battle', 2002, 0.  )
#  ('Big Mutha Truckers', 2002, 0.  ) ('Blade II', 2002, 0.  )
#  ('Blade II', 2002, 0.  ) ('Blood Omen 2', 2002, 0.  )
#  ('Blood Wake', 2001, 0.  ) ('BloodRayne', 2002, 0.  )
#  ('BloodRayne', 2002, 0.  ) ('Bloody Roar: Primal Fury', 2002, 0.  )
#  ('Bombastic', 2002, 0.  ) ('Bomberman Jetters', 2002, 0.  )
#  ('Bomberman Party Edition', 1998, 0.  ) ('Breath of Fire II', 2001, 0.  )
#  ('Breath of Fire: Dragon Quarter', 2002, 0.  )
#  ("Britney's Dance Beat", 2002, 0.  ) ("Britney's Dance Beat", 2002, 0.  )
#  ('Broken Sword: The Shadow of the Templars', 2002, 0.  )
#  ('Burnout', 2001, 0.  ) ('Burnout', 2002, 0.  )
#  ('Buzz Lightyear of Star Command', 2000, 0.  )
#  ('Capcom vs. SNK 2 EO', 2002, 0.  )
#  ('Casper: Spirit Dimensions', 2001, 0.  )
#  ('Castlevania Chronicles', 2001, 0.  ) ('Cel Damage', 2001, 0.  )
#  ('Cel Damage', 2002, 0.  ) ('Chase: Hollywood Stunt Driver', 2002, 0.  )
#  ('Chicken Run', 2000, 0.  ) ('Circus Maximus: Chariot Wars', 2002, 0.  )
#  ('City Crisis', 2001, 0.  ) ('Colin McRae Rally 3', 2002, 0.  )
#  ('Colony Wars', 1997, 0.  )
#  ('Combat Flight Simulator 3: Battle for Europe', 2002, 0.  )
#  ('Commandos 2: Men of Courage', 2002, 0.  )
#  ('Commandos 2: Men of Courage', 2002, 0.  ) ('Conflict Zone', 2002, 0.  )
#  ('Cossacks: European Wars', 2001, 0.  ) ('Culdcept', 2002, 0.  )
#  ('Dance Dance Revolution Disney Mix', 2000, 0.  )
#  ('Dark Angel: Vampire Apocalypse', 2001, 0.  )
#  ('Dark Summit', 2002, 0.  ) ('Darkened Skye', 2002, 0.  )
#  ('Darkstone', 2001, 0.  ) ('Dave Mirra Freestyle BMX', 2000, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX 2', 2001, 0.  )
#  ('Dave Mirra Freestyle BMX: Maximum Remix', 2001, 0.  )
#  ('Dead to Rights', 2002, 0.  ) ('DemiKids: Light Version', 2002, 0.  )
#  ('Destruction Derby Raw', 2000, 0.  ) ('Deus Ex', 2000, 0.  )
#  ('Deus Ex: The Conspiracy', 2002, 0.  ) ('Diablo', 1996, 0.  )
#  ('Diablo II', 2000, 0.  ) ('Diablo II: Lord of Destruction', 2001, 0.  )
#  ('Die Hard: Vendetta', 2002, 0.  )
#  ('Digimon Digital Card Battle', 1999, 0.  )
#  ('Digimon Rumble Arena', 2001, 0.  )
#  ('Disney Sports Skateboarding', 2002, 0.  )
#  ("Disney's Aladdin in Nasira's Revenge", 2000, 0.  )
#  ("Disney's Atlantis: The Lost Empire", 2001, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2000, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2000, 0.  )
#  ("Disney's Donald Duck: Goin' Quackers", 2002, 0.  )
#  ("Disney's Magical Mirror Starring Mickey Mouse", 2002, 0.  )
#  ("Disney's PK: Out of the Shadows", 2002, 0.  )
#  ("Disney's Party", 2002, 0.  )
#  ("Disney's Stitch: Experiment 626", 2002, 0.  )
#  ("Disney's Tarzan Untamed", 2001, 0.  )
#  ("Disney's Tarzan Untamed", 2001, 0.  )
#  ("Disney's The Emperor's New Groove", 2000, 0.  )
#  ("Disney's The Lion King: Simba's Mighty Adventure", 2000, 0.  )
#  ('Doom', 1992, 0.  ) ('Doom', 2001, 0.  ) ('Dragon Rage', 2001, 0.  )
#  ('Dragon Valor', 1999, 0.  ) ("Drakan: The Ancients' Gates", 2002, 0.  )
#  ('Driven', 2001, 0.  ) ('Dropship: United Peace Force', 2002, 0.  )
#  ('Duke Nukem: Land of the Babes', 2000, 0.  )
#  ('Dynasty Warriors 3', 2002, 0.  )
#  ('E.T. The Extra-Terrestrial', 2001, 0.  )
#  ('ECW Anarchy Rulz', 1999, 0.  )
#  ('ESPN Winter X Games: Snowboarding 2002', 2000, 0.  )
#  ('ESPN X Games Skateboarding', 2001, 0.  ) ('Earthworm Jim', 2001, 0.  )
#  ('Earthworm Jim 2', 2002, 0.  )
#  ('Ecco the Dolphin: Defender of the Future', 2002, 0.  )
#  ('Egg Mania: Eggstreme Madness', 2002, 0.  ) ('Empire Earth', 2001, 0.  )
#  ('Enclave', 2002, 0.  ) ('Endgame', 2002, 0.  )
#  ('Ephemeral Fantasia', 2000, 0.  )
#  ('Escape From Monkey Island', 2001, 0.  ) ('EverBlue 2', 2002, 0.  )
#  ('Evil Dead: Hail to the King', 2000, 0.  )
#  ('Evolution Skateboarding', 2002, 0.  ) ('Evolution Worlds', 2002, 0.  )
#  ('F1 2001', 2001, 0.  ) ('F1 2001', 2001, 0.  ) ('F1 2002', 2002, 0.  )
#  ('FIFA 2001 Major League Soccer', 2000, 0.  )
#  ('FIFA Soccer 2002', 2001, 0.  ) ('FIFA Soccer 2002', 2001, 0.  )
#  ('FIFA Soccer 2002', 2001, 0.  ) ('FIFA Soccer 2003', 2002, 0.  )
#  ('Fatal Frame', 2001, 0.  ) ('Fatal Frame', 2002, 0.  )
#  ('Fear Effect 2: Retro Helix', 2001, 0.  )
#  ('Ferrari F355 Challenge', 2002, 0.  ) ('Fighter Maker 2', 2002, 0.  )
#  ('Final Fantasy Anthology', 1999, 0.  )
#  ('Final Fantasy Chronicles', 2001, 0.  ) ('Ford Racing', 2001, 0.  )
#  ('Formula One 2001', 2001, 0.  ) ('Frequency', 2001, 0.  )
#  ("Frogger 2: Swampy's Revenge", 1999, 0.  )
#  ('Frogger Beyond', 2002, 0.  ) ('Frogger: The Great Quest', 2001, 0.  )
#  ("Fur Fighters: Viggo's Revenge", 2001, 0.  )
#  ('Fuzion Frenzy', 2001, 0.  ) ('GT Advance 2: Rally Racing', 2001, 0.  )
#  ('Gadget Racers', 2000, 0.  ) ('Galerians: Ash', 2002, 0.  )
#  ('Gauntlet: Dark Legacy', 2001, 0.  )
#  ('Gauntlet: Dark Legacy', 2002, 0.  )
#  ('Gauntlet: Dark Legacy', 2002, 0.  )
#  ("Gekido Advance: Kintaro's Revenge", 2002, 0.  )
#  ('Giants: Citizen Kabuto', 2001, 0.  ) ('Gitaroo Man', 2001, 0.  )
#  ('Godai: Elemental Force', 2002, 0.  )
#  ('Grand Prix Challenge', 2002, 0.  ) ('Grand Theft Auto 2', 1998, 0.  )
#  ('Grand Theft Auto III', 2002, 0.  ) ('Grandia', 1999, 0.  )
#  ('Grandia II', 2002, 0.  )
#  ('Gravity Games Bike: Street Vert Dirt', 2002, 0.  )
#  ('Guilty Gear X', 2001, 0.  )
#  ('Guilty Gear X: Advance Edition', 2002, 0.  ) ('Gun Metal', 2002, 0.  )
#  ('Gundam Battle Assault', 1998, 0.  ) ('Gungrave', 2002, 0.  )
#  ('Gunvalkyrie', 2002, 0.  ) ('HBO Boxing', 2000, 0.  )
#  ('Half-Life', 2001, 0.  )
#  ('Harry Potter and the Chamber of Secrets', 2002, 0.  )
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.  )
#  ('Herdy Gerdy', 2002, 0.  ) ('Hidden Invasion', 2001, 0.  )
#  ('Hogs of War', 2000, 0.  ) ('Homeworld', 1998, 0.  )
#  ('Hoshigami: Ruining Blue Earth', 2001, 0.  )
#  ('Hot Wheels Velocity X', 2002, 0.  )
#  ('Hunter: The Reckoning', 2002, 0.  ) ('ICO', 2001, 0.  )
#  ('IL-2 Sturmovik', 2001, 0.  ) ('Icewind Dale II', 2002, 0.  )
#  ('Impossible Creatures', 2002, 0.  ) ('Incredible Crisis', 1999, 0.  )
#  ('Jade Cocoon 2', 2001, 0.  ) ("James Cameron's Dark Angel", 2002, 0.  )
#  ('Jeremy McGrath Supercross World', 2001, 0.  )
#  ('Jeremy McGrath Supercross World', 2002, 0.  )
#  ('Jimmy Neutron: Boy Genius', 2002, 0.  )
#  ('Jonny Moseley Mad Trix', 2001, 0.  )
#  ('Jurassic Park III: Park Builder', 2001, 0.  )
#  ('KISS Pinball', 2001, 0.  ) ('Kabuki Warriors', 2001, 0.  )
#  ('Kakuto Chojin', 2002, 0.  ) ("Kelly Slater's Pro Surfer", 2002, 0.  )
#  ("Kelly Slater's Pro Surfer", 2002, 0.  ) ('Kinetica', 2001, 0.  )
#  ("King's Field: The Ancient City", 2001, 0.  )
#  ('Klonoa 2: Dream Champ Tournament', 2002, 0.  )
#  ('Knockout Kings 2001', 2000, 0.  ) ('Knockout Kings 2003', 2002, 0.  )
#  ('La Pucelle: Tactics', 2002, 0.  ) ('Legaia 2: Duel Saga', 2001, 0.  )
#  ('Legends of Wrestling', 2002, 0.  ) ('Legends of Wrestling', 2002, 0.  )
#  ('Legends of Wrestling II', 2002, 0.  )
#  ('Legends of Wrestling II', 2002, 0.  )
#  ('Legion: The Legend of Excalibur', 2002, 0.  )
#  ('Looney Tunes: Sheep Raider', 2001, 0.  )
#  ('Lufia: The Ruins of Lore', 2002, 0.  )
#  ('Lunar 2: Eternal Blue Complete', 1999, 0.  )
#  ('Lunar Legend', 2002, 0.  ) ('MDK2 Armageddon', 2001, 0.  )
#  ('MLB 2002', 2001, 0.  ) ('MLB SlugFest 20-03', 2002, 0.  )
#  ('MLB SlugFest 20-03', 2002, 0.  ) ('MTV Music Generator 2', 2001, 0.  )
#  ('MX 2002 Featuring Ricky Carmichael', 2001, 0.  )
#  ('MXRider', 2001, 0.  ) ('Mad Dash Racing', 2001, 0.  )
#  ('Madden NFL 2001', 2000, 0.  ) ('Madden NFL 2002', 2001, 0.  )
#  ('Mafia', 2002, 0.  ) ('Magic Pengel: The Quest for Color', 2002, 0.  )
#  ('Martian Gothic: Unification', 2001, 0.  )
#  ("Mat Hoffman's Pro BMX", 2001, 0.  ) ('Max Payne', 2001, 0.  )
#  ('Max Payne', 2001, 0.  ) ('Maximo: Ghosts to Glory', 2001, 0.  )
#  ('Maximum Capacity: Hotel Giant', 2002, 0.  )
#  ('Medal of Honor', 1998, 0.  )
#  ('Medal of Honor: Underground', 2000, 0.  )
#  ('Medal of Honor: Underground', 2002, 0.  ) ('Metal Dungeon', 2002, 0.  )
#  ('Metal Slug X', 2001, 0.  ) ('MetropolisMania', 2001, 0.  )
#  ('Microsoft Train Simulator', 2001, 0.  )
#  ('Midnight Club: Street Racing', 2001, 0.  )
#  ('Minority Report: Everybody Runs', 2002, 0.  )
#  ('Monster Rancher Advance 2', 2002, 0.  )
#  ('Monsters Inc Scream Team', 2001, 0.  )
#  ('Mortal Kombat: Deadly Alliance', 2002, 0.  )
#  ('Mortal Kombat: Special Forces', 2000, 0.  ) ('MotoGP', 2002, 0.  )
#  ('Motocross Mania', 2001, 0.  ) ('Myst III: Exile', 2002, 0.  )
#  ('Mystic Heroes', 2002, 0.  ) ('NASCAR 2001', 2000, 0.  )
#  ('NASCAR 2001', 2000, 0.  ) ('NASCAR Thunder 2002', 2001, 0.  )
#  ('NASCAR Thunder 2002', 2001, 0.  )
#  ('NASCAR: Dirt to Daytona', 2002, 0.  ) ('NBA 2K2', 2002, 0.  )
#  ('NBA 2K2', 2002, 0.  ) ('NBA Live 2001', 2000, 0.  )
#  ('NBA Live 2002', 2001, 0.  ) ('NBA Live 2002', 2001, 0.  )
#  ('NBA Live 2002', 2001, 0.  ) ('NBA ShootOut 2003', 2002, 0.  )
#  ('NBA Starting Five', 2002, 0.  ) ('NBA Street', 2001, 0.  )
#  ('NCAA College Basketball 2K3', 2002, 0.  )
#  ('NCAA College Basketball 2K3', 2002, 0.  )
#  ('NCAA Final Four 2002', 2001, 0.  ) ('NCAA Final Four 2003', 2002, 0.  )
#  ('NCAA Football 2002', 2001, 0.  ) ('NCAA Football 2003', 2002, 0.  )
#  ('NFL 2K1', 2000, 0.  ) ('NFL 2K2', 2001, 0.  ) ('NFL 2K3', 2002, 0.  )
#  ('NFL Blitz 20-02', 2002, 0.  ) ('NFL Blitz 20-03', 2002, 0.  )
#  ('NFL Fever 2002', 2000, 0.  ) ('NFL GameDay 2002', 2001, 0.  )
#  ('NFL GameDay 2002', 2001, 0.  )
#  ('NFL Quarterback Club 2002', 2001, 0.  ) ('NHL 2001', 2000, 0.  )
#  ('NHL 2001', 2000, 0.  ) ('NHL 2002', 2001, 0.  )
#  ('NHL 2002', 2001, 0.  ) ('NHL 2003', 2002, 0.  )
#  ('NHL 2003', 2002, 0.  ) ('NHL 2K3', 2002, 0.  ) ('NHL 2K3', 2002, 0.  )
#  ('NHL 2K3', 2002, 0.  ) ('NHL FaceOff 2001', 2001, 0.  )
#  ('NHL Hitz 20-02', 2001, 0.  ) ('NHL Hitz 20-02', 2001, 0.  )
#  ('NHL Hitz 20-02', 2001, 0.  ) ('NHL Hitz 20-03', 2002, 0.  )
#  ('NHL Hitz 20-03', 2002, 0.  ) ('NHL Hitz 20-03', 2002, 0.  )
#  ('Namco Museum', 2001, 0.  ) ('Need For Speed: High Stakes', 1999, 0.  )
#  ('Need for Speed: Porsche Unleashed', 1999, 0.  )
#  ('Neverwinter Nights', 2002, 0.  )
#  ('Nickelodeon Party Blast', 2002, 0.  ) ('NightCaster', 2002, 0.  )
#  ('NightCaster II: Equinox', 2002, 0.  ) ('Ninja Assault', 2002, 0.  )
#  ("Oddworld: Abe's Exoddus", 1998, 0.  )
#  ("Oddworld: Abe's Oddysee", 1997, 0.  )
#  ("Oddworld: Munch's Oddysee", 2001, 0.  ) ('Oni', 2001, 0.  )
#  ('Orphen: Scion of Sorcery', 2000, 0.  )
#  ('P.T.O. IV: Pacific Theater of Operations', 2002, 0.  )
#  ('PaRappa The Rapper 2', 2001, 0.  ) ('Pac-Man Fever', 2001, 0.  )
#  ('Parasite Eve II', 1999, 0.  ) ('Paris-Dakar Rally', 2001, 0.  )
#  ('Phantasy Star Collection', 2002, 0.  )
#  ('Pirates: The Legend of Black Kat', 2002, 0.  )
#  ('Planescape: Torment', 1998, 0.  ) ('Point Blank 3', 2000, 0.  )
#  ('Portal Runner', 2001, 0.  ) ('Power Rangers: Wild Force', 2002, 0.  )
#  ('Pro Race Driver', 2002, 0.  ) ('Project Eden', 2001, 0.  )
#  ('Pryzm Chapter One: The Dark Unicorn', 2002, 0.  )
#  ('Quake III: Revolution', 2001, 0.  ) ('Quantum Redshift', 2002, 0.  )
#  ('RC Revenge Pro', 2000, 0.  ) ('RLH: Run Like Hell', 2002, 0.  )
#  ('RPG Maker II', 2002, 0.  ) ('RayStorm', 1997, 0.  )
#  ('Rayman 2: Revolution', 2000, 0.  ) ('Rayman Advance', 2001, 0.  )
#  ('Rayman Arena', 2001, 0.  ) ('Rayman Arena', 2002, 0.  )
#  ('Red Faction', 2001, 0.  ) ('RedCard 20-03', 2002, 0.  )
#  ('RedCard 20-03', 2002, 0.  ) ('RedCard 20-03', 2002, 0.  )
#  ('Reign of Fire', 2002, 0.  ) ('Reign of Fire', 2002, 0.  )
#  ('Rez', 2001, 0.  ) ('Riding Spirits', 2002, 0.  )
#  ('Ring of Red', 2000, 0.  ) ('Road Trip', 2002, 0.  )
#  ('Robot Alchemic Drive', 2002, 0.  ) ('Robotech: Battlecry', 2002, 0.  )
#  ('Robotech: The Macross Saga', 2002, 0.  ) ('Rocky', 2002, 0.  )
#  ('Rollcage Stage II', 2000, 0.  ) ('Rumble Racing', 2001, 0.  )
#  ('Rune: Viking Warlord', 2001, 0.  ) ('SSX Tricky', 2001, 0.  )
#  ('SSX Tricky', 2001, 0.  ) ('SSX Tricky', 2001, 0.  )
#  ('Sabrina The Teenage Witch: Potion Commotion', 2002, 0.  )
#  ('Saiyuki: Journey West', 1999, 0.  ) ('Salt Lake 2002', 2002, 0.  )
#  ('Sega Soccer Slam', 2002, 0.  ) ('Sega Soccer Slam', 2002, 0.  )
#  ('Serious Sam', 2002, 0.  ) ('Shadow Man: 2econd Coming', 2002, 0.  )
#  ("Shaun Palmer's Pro Snowboarder", 2001, 0.  ) ('Shifters', 2002, 0.  )
#  ('Shrek', 2001, 0.  ) ('Shrek Extra Large', 2002, 0.  )
#  ('Shrek Super Party', 2002, 0.  ) ('Shrek Super Party', 2002, 0.  )
#  ('Silent Hill 2', 2001, 0.  )
#  ('Silent Hill 2: Restless Dreams', 2001, 0.  )
#  ('Silent Scope', 2002, 0.  ) ('Silhouette Mirage', 1998, 0.  )
#  ('Silpheed: The Lost Planet', 2000, 0.  ) ('SimCity', 1988, 0.  )
#  ('Sky Odyssey', 2000, 0.  )
#  ('Smash Court Tennis Pro Tournament', 2002, 0.  )
#  ("Smuggler's Run", 2000, 0.  ) ("Smuggler's Run", 2002, 0.  )
#  ("Smuggler's Run: Warzones", 2002, 0.  ) ('Sneakers', 2002, 0.  )
#  ('Soldier of Fortune: Gold Edition', 2001, 0.  )
#  ('Soul Reaver 2', 2001, 0.  )
#  ("Space Channel 5: Ulala's Cosmic Attack", 2002, 0.  )
#  ('Spec Ops: Ranger Elite', 2001, 0.  )
#  ("Spider-Man: Mysterio's Menace", 2001, 0.  ) ('SplashDown', 2001, 0.  )
#  ('SpongeBob SquarePants: Revenge of the Flying Dutchman', 2002, 0.  )
#  ('Spy Hunter', 2001, 0.  ) ('Spyro: Season of Ice', 2001, 0.  )
#  ('Spyro: Year of the Dragon', 2000, 0.  )
#  ('Star Trek: Voyager Elite Force', 2001, 0.  )
#  ('Star Wars Racer Revenge', 2002, 0.  )
#  ('Star Wars: Demolition', 2000, 0.  ) ('Star Wars: Obi-Wan', 2001, 0.  )
#  ('Star Wars: Super Bombad Racing', 2001, 0.  ) ('StarCraft', 1998, 0.  )
#  ('Street Fighter Alpha 3', 2002, 0.  ) ('Stretch Panic', 2001, 0.  )
#  ('Strider 2', 2000, 0.  ) ('Strikers 1945', 1998, 0.  )
#  ('Stronghold', 2001, 0.  ) ('Stunt GP', 2001, 0.  )
#  ('Summoner', 2000, 0.  ) ('Summoner 2', 2002, 0.  )
#  ('Sunny Garcia Surfing', 2001, 0.  )
#  ("Super Ghouls 'n Ghosts", 2002, 0.  )
#  ('Super Puzzle Fighter II Turbo', 1996, 0.  )
#  ('Super Street Fighter II: Turbo Revival', 2001, 0.  )
#  ('Supercar Street Challenge', 2001, 0.  )
#  ('Superman: The Man of Steel', 2002, 0.  ) ('Surfing H3O', 2000, 0.  )
#  ('Swingerz Golf', 2002, 0.  ) ('Syberia', 2002, 0.  )
#  ('Syphon Filter 3', 2001, 0.  ) ('Taz Wanted', 2002, 0.  )
#  ('Taz Wanted', 2002, 0.  ) ('Tekken Advance', 2001, 0.  )
#  ('Tenchu 2: Birth of the Stealth Assassins', 2000, 0.  )
#  ('Test Drive Off-Road Wide Open', 2001, 0.  )
#  ('The King of Fighters EX2: Howling Blood', 2002, 0.  )
#  ("The Legend of Alon D'ar", 2001, 0.  )
#  ('The Longest Journey', 1999, 0.  ) ('The Mummy Returns', 2001, 0.  )
#  ('The Operative: No One Lives Forever', 2002, 0.  )
#  ('The Powerpuff Girls: Chemical X-Traction', 2001, 0.  )
#  ('The Scorpion King: Rise of the Akkadian', 2002, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  )
#  ('The Simpsons: Road Rage', 2001, 0.  ) ('The Sims', 2000, 0.  )
#  ('The Sims Deluxe', 2002, 0.  ) ('The Sims: Hot Date', 2001, 0.  )
#  ('The Sims: House Party', 2001, 0.  )
#  ('The Sims: Livin Large', 2000, 0.  )
#  ('The Terminator: Dawn of Fate', 2002, 0.  ) ('The Thing', 2002, 0.  )
#  ('The Weakest Link', 2001, 0.  )
#  ('Theme Park Roller Coaster', 2000, 0.  )
#  ('Thunderstrike: Operation Phoenix', 2001, 0.  )
#  ('Time Crisis II', 2001, 0.  ) ('Time Crisis: Project Titan', 2001, 0.  )
#  ('TimeSplitters', 2000, 0.  ) ('Tomb Raider', 1996, 0.  )
#  ('Tomb Raider: The Prophecy', 2002, 0.  )
#  ("Tony Hawk's Pro Skater 2", 2001, 0.  )
#  ("Tony Hawk's Pro Skater 2x", 2001, 0.  )
#  ("Tony Hawk's Pro Skater 3", 2001, 0.  )
#  ('Top Gun: Combat Zones', 2001, 0.  )
#  ('Top Gun: Combat Zones', 2002, 0.  ) ('Toy Story Racer', 2001, 0.  )
#  ('Transworld Snowboarding', 2002, 0.  ) ('Transworld Surf', 2002, 0.  )
#  ('Turok: Evolution', 2002, 0.  ) ('Twisted Metal: Black', 2001, 0.  )
#  ('Ty the Tasmanian Tiger', 2002, 0.  )
#  ('Ultimate Fighting Championship', 2000, 0.  )
#  ('Ultimate Fighting Championship: Throwdown', 2002, 0.  )
#  ('Universal Studios Theme Parks Adventure', 2001, 0.  )
#  ('Unreal Tournament', 2000, 0.  ) ('Unreal Tournament 2003', 2002, 0.  )
#  ('V-Rally 3', 2002, 0.  ) ('Vampire Night', 2001, 0.  )
#  ('Vanguard Bandits', 1998, 0.  ) ('WarJetz', 2001, 0.  )
#  ('Warcraft III: Reign of Chaos', 2002, 0.  )
#  ('Warriors of Might and Magic', 2001, 0.  ) ('Whirl Tour', 2002, 0.  )
#  ('Whirl Tour', 2002, 0.  ) ('WinBack: Covert Operations', 2000, 0.  )
#  ('WipEout 3', 1999, 0.  ) ('WipEout Fusion', 2002, 0.  )
#  ('WipEout XL', 1996, 0.  )
#  ('Wizardry: Tale of the Forsaken Land', 2001, 0.  )
#  ('Wolfenstein 3D', 2002, 0.  )
#  ('Woody Woodpecker: Escape from Buzz Buzzard Park', 2001, 0.  )
#  ('World Destruction League: Thunder Tanks', 2000, 0.  )
#  ('World Destruction League: Thunder Tanks', 2000, 0.  )
#  ('World Tour Soccer 2002', 2001, 0.  )
#  ('World Tour Soccer 2003', 2002, 0.  )
#  ("World's Scariest Police Chases", 2001, 0.  )
#  ('Worms World Party', 2001, 0.  ) ('X-Men: Mutant Academy 2', 2001, 0.  )
#  ('X-Men: Next Dimension', 2002, 0.  )
#  ('XGIII: Extreme G Racing', 2001, 0.  ) ('XXX', 2002, 0.  )
#  ('Yanya Caballista: City Skater', 2001, 0.  )
#  ('Zone of the Enders: The Fist of Mars', 2001, 0.  )
#  ('ZooCube', 2002, 0.  ) ('Madden NFL 2002', 2001, 0.01)
#  ('Phantom Crash', 2002, 0.01) ("Tony Hawk's Pro Skater 3", 2001, 0.01)
#  ('Colin McRae Rally 2.0', 2000, 0.02) ('Colin McRae Rally 3', 2002, 0.02)
#  ('Crazy Taxi', 2001, 0.02) ('Crazy Taxi 3: High Roller', 2002, 0.02)
#  ('Disney Golf', 2002, 0.02) ('Driver', 1999, 0.02)
#  ('Driver 2', 2000, 0.02) ('EÂ·OÂ·E: Eve of Extinction', 2002, 0.02)
#  ('F1 2002', 2002, 0.02) ('Le Mans 24 Hours', 2001, 0.02)
#  ('Midnight Club: Street Racing', 2000, 0.02) ('Spider-Man', 2000, 0.02)
#  ('Spider-Man 2: Enter: Electro', 2001, 0.02)
#  ('Star Wars: Starfighter', 2001, 0.02) ('Steel Battalion', 2002, 0.02)
#  ("Tony Hawk's Pro Skater", 1999, 0.02)
#  ("Tony Hawk's Pro Skater 2", 2000, 0.02)
#  ("Tony Hawk's Pro Skater 3", 2001, 0.02)
#  ('JSRF: Jet Set Radio Future', 2002, 0.03) ('Lowrider', 2002, 0.03)
#  ('Otogi: Myth of Demons', 2002, 0.03) ('Sega GT 2002', 2002, 0.03)
#  ('Shadow of Destiny', 2001, 0.03)
#  ('Star Wars Rogue Leader: Rogue Squadron II', 2001, 0.03)
#  ('Virtua Striker 2002', 2002, 0.03)
#  ('Castlevania: Harmony of Dissonance', 2002, 0.04)
#  ('Crimson Sea', 2002, 0.04) ('Forever Kingdom', 2001, 0.04)
#  ('Lost Kingdoms', 2002, 0.04) ('Mystic Heroes', 2002, 0.04)
#  ('Panzer Dragoon Orta', 2002, 0.04) ('Bloody Roar 3', 2001, 0.05)
#  ('Castlevania: Circle of the Moon', 2001, 0.05)
#  ('Genma Onimusha', 2002, 0.05) ('Madden NFL 2001', 2000, 0.05)
#  ('Max Payne', 2001, 0.05) ('Namco Museum', 2001, 0.05)
#  ('Pac-Man Collection', 2001, 0.05) ('Project Gotham Racing', 2001, 0.05)
#  ('Rave Master', 2002, 0.05) ('The Typing of the Dead', 2000, 0.05)
#  ('Bomberman Generation', 2002, 0.06) ('Breath of Fire', 2001, 0.06)
#  ('Crazy Taxi', 2001, 0.06) ('Gallop Racer 2001', 2001, 0.06)
#  ('Kengo: Master of Bushido', 2000, 0.06)
#  ('Lunar: Silver Star Story Complete', 1998, 0.06)
#  ('Murakumo: Renegade Mech Pursuit', 2002, 0.06) ('SSX', 2000, 0.06)
#  ('Crazy Taxi 2', 2001, 0.07) ('G1 Jockey 3', 2002, 0.07)
#  ('Dark Cloud', 2000, 0.08) ('Dino Stalker', 2002, 0.08)
#  ('Final Fight One', 2001, 0.08) ('Halo: Combat Evolved', 2001, 0.08)
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.08)
#  ("Klonoa 2: Lunatea's Veil", 2001, 0.08)
#  ('Okage: Shadow King', 2001, 0.08) ('Half-Life', 1997, 0.09)
#  ('Shining Soul', 2002, 0.09) ('Skies of Arcadia', 2000, 0.09)
#  ('Wave Race: Blue Storm', 2001, 0.09) ('Dead or Alive', 1998, 0.1 )
#  ('Eternal Ring', 2000, 0.1 )
#  ('InuYasha: A Feudal Fairy Tale', 2002, 0.1 )
#  ('James Bond 007: Agent Under Fire', 2001, 0.1 )
#  ('K-1 World Grand Prix', 2002, 0.1 ) ('Mega Man Legends 2', 2000, 0.1 )
#  ('Shadow Hearts', 2001, 0.1 ) ('Super Monkey Ball', 2001, 0.1 )
#  ('Clock Tower 3', 2002, 0.12)
#  ('Clock Tower II: The Struggle Within', 1998, 0.12)
#  ('Extermination', 2001, 0.12)
#  ('Gallop Racer 2003: A New Breed', 2002, 0.12)
#  ('Harvest Moon: Back to Nature', 1999, 0.12)
#  ('Sonic Adventure 2', 2001, 0.12) ('Sega GT', 2000, 0.13)
#  ('Tomb Raider', 1996, 0.13) ('Zone of the Enders', 2001, 0.13)
#  ("Harry Potter and the Sorcerer's Stone", 2001, 0.14)
#  ('Monster Rancher 3', 2001, 0.14) ('MotoGP', 2000, 0.14)
#  ('Cubivore: Survival of the Fittest', 2002, 0.15)
#  ('Disaster Report', 2002, 0.15) ('EverGrace', 2000, 0.15)
#  ('Jak and Daxter: The Precursor Legacy', 2001, 0.15)
#  ('Shenmue II', 2001, 0.15) ('Tokyo Xtreme Racer Zero', 2000, 0.15)
#  ('Digimon World 2', 2000, 0.16) ('Dynasty Tactics', 2002, 0.16)
#  ('Guilty Gear X2', 2002, 0.16) ('Mega Man X6', 2001, 0.16)
#  ('Romance of the Three Kingdoms VII', 2000, 0.16)
#  ('.hack//Outbreak Part 3', 2002, 0.17) ('Mister Mosquito', 2001, 0.17)
#  ('Bust A Groove 2', 1999, 0.18)
#  ('Armored Core 2: Another Age', 2001, 0.19) ('Crash Bash', 2000, 0.19)
#  ('Fantavision', 2000, 0.19) ('Phantasy Star Online Ver. 2', 2001, 0.19)
#  ('Romance of the Three Kingdoms VIII', 2002, 0.19)
#  ('Grandia II', 2000, 0.2 ) ('Kessen II', 2001, 0.2 )
#  ('Mega Man X5', 2000, 0.2 ) ('Phantasy Star Online', 2000, 0.2 )
#  ('Street Fighter EX3', 2000, 0.2 )
#  ('Castlevania: Symphony of the Night', 1997, 0.21)
#  ('Sonic Adventure 2 Battle', 2001, 0.21) ('Capcom vs. SNK', 2000, 0.22)
#  ('Mega Man Battle Network', 2001, 0.22) ('Sonic Advance', 2001, 0.22)
#  ('Armored Core 2', 2000, 0.23)
#  ('Crash Bandicoot: The Wrath of Cortex', 2001, 0.24)
#  ('Dead or Alive 3', 2001, 0.24) ('Grandia Xtreme', 2002, 0.25)
#  ('Mobile Suit Gundam: Zeonic Front', 2001, 0.25)
#  ('Way of the Samurai', 2002, 0.25)
#  ('Tenchu: Stealth Assassins', 1997, 0.27) ('Dino Crisis 2', 2000, 0.28)
#  ('Persona 2: Eternal Punishment', 2000, 0.28) ('RPG Maker', 1997, 0.29)
#  ('Resident Evil: Survivor', 2000, 0.29) ('Wild ARMs 3', 2002, 0.29)
#  ('Capcom vs. SNK 2: Mark of the Millennium 2001', 2001, 0.3 )
#  ('Grand Theft Auto III', 2001, 0.3 ) ('Silent Hill', 1999, 0.3 )
#  ('Vagrant Story', 2000, 0.3 )
#  ('Tactics Ogre: The Knight of Lodis', 2001, 0.31)
#  ('Ape Escape', 1999, 0.32) ('Breath of Fire IV', 2000, 0.34)
#  ('Dynasty Warriors 2', 2000, 0.34)
#  ('Resident Evil - Code: Veronica X', 2001, 0.34)
#  ('SoulCalibur', 1999, 0.34)
#  ('Mobile Suit Gundam: Journey to Jaburo', 2000, 0.36)
#  ('F-Zero: Maximum Velocity', 2001, 0.37)
#  ('Ace Combat 04: Shattered Skies', 2001, 0.38)
#  ('Ape Escape 2', 2002, 0.38) ('Shenmue', 1999, 0.38)
#  ('Suikoden II', 1998, 0.38) ('The Bouncer', 2000, 0.38)
#  ("Victorious Boxers: Ippo's Road to Glory", 2000, 0.38)
#  ('The Legend of Dragoon', 1999, 0.39) ('Golden Sun', 2001, 0.4 )
#  ('Kessen', 2000, 0.41) ('Bushido Blade', 1997, 0.43)
#  ('Crash Team Racing', 1999, 0.44) ("Luigi's Mansion", 2001, 0.46)
#  ('Street Fighter Alpha 3', 1998, 0.51)
#  ('Tekken Tag Tournament', 2000, 0.51) ('Seaman', 1999, 0.52)
#  ('Battle Arena Toshinden', 1994, 0.53) ('Wario Land 4', 2001, 0.54)
#  ('Ace Combat 2', 1997, 0.56) ('Pikmin', 2001, 0.56)
#  ('Unlimited Saga', 2002, 0.56) ('Valkyrie Profile', 1999, 0.63)
#  ('Devil May Cry', 2001, 0.64) ('Brave Fencer Musashi', 1998, 0.65)
#  ('Tales of Destiny II', 2000, 0.66) ('Chrono Cross', 1999, 0.69)
#  ('ISS Pro Evolution', 1998, 0.71)
#  ('Star Ocean: The Second Story', 1998, 0.72)
#  ('Dynasty Warriors 3: Xtreme Legends', 2002, 0.74)
#  ('Monster Rancher', 1997, 0.74) ('Ridge Racer V', 2000, 0.75)
#  ('Metal Gear Solid', 1998, 0.78) ('R4: Ridge Racer Type 4', 1998, 0.79)
#  ('Metal Gear Solid 2: Sons of Liberty', 2001, 0.87)
#  ('Mobile Suit Gundam: Federation vs. Zeon', 2001, 0.88)
#  ('Xenogears', 1998, 0.89) ('Super Mario Advance', 2001, 0.91)
#  ('Animal Crossing', 2001, 0.99) ('Mario Kart: Super Circuit', 2001, 0.99)
#  ('Parasite Eve', 1998, 1.05) ('Dynasty Warriors 3', 2001, 1.07)
#  ('Onimusha: Warlords', 2001, 1.09) ('Resident Evil', 1996, 1.11)
#  ('World Soccer Winning Eleven 6 International', 2002, 1.16)
#  ('Final Fantasy Tactics', 1997, 1.34) ('Tekken 2', 1996, 1.36)
#  ('Hot Shots Golf 3', 2001, 1.38) ('Super Smash Bros. Melee', 2001, 1.39)
#  ('Tekken 3', 1998, 1.4 ) ('Crash Bandicoot 3: Warped', 1998, 1.42)
#  ('PaRappa The Rapper', 1996, 1.46) ('Gran Turismo 2', 1999, 1.69)
#  ('Gran Turismo 3: A-Spec', 2001, 1.87) ('Resident Evil 2', 1998, 2.02)
#  ('Gran Turismo', 1997, 2.54) ('Final Fantasy X', 2001, 2.73)
#  ('Final Fantasy IX', 2000, 2.78) ('Final Fantasy VII', 1997, 3.28)
#  ('Final Fantasy VIII', 1999, 3.63)]
